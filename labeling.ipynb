# %%
import json

with open('data/trainingData/labels.json', 'r') as file:
        file = json.load(file)

file
# Out:
# {'study_types': {'Quantitative': {'Experimental': ['Randomized (controlled) trial',
#     'Natural experiments'],
#    'Quasi-experimental': ['Regression discontinuity',
#     'Difference-in-difference',
#     'Instrumental variable design',
#     'Natural experiments'],
#    'Non-experimental': ['Observational',
#     'Cross-sectional',
#     'Longitudinal / Panel'],
#    'Meta-analysis': ['Meta-analysis']},
#   'Qualitative': {'Methods': ['Case-study',
#     'Ethnography',
#     'First-hand observations',
#     'Interviews',
#     'Focus groups',
#     'Recordings'],
#    'Mixed Method': ['Systematic review']}},
#  'poverty_contexts': {'Low resource level (Difficulty in meeting basic needs)': 'Low resource level',
#   'Resource volatility (Income fluctuations, emergency expenses)': 'Resource volatility',
#   'Physical environment (Neighborhood quality, noise, violence, crime)': 'Physical environment',
#   'Human capital inputs (School quality, health/nutrition, social services)': 'Human capital inputs',
#   'Social environment (Discrimination, stereotypes, stigma)': 'Social environment'},
#  'mechanisms': {'Cognitive Function': ['Attention',
#    'Cognitive flexibility',
#    'Executive control',
#    'Executive function',
#    'Fluid intelligence',
#    'Memory',
#    'Working memory'],
#   'Mental Health': ['Anxiety', 'Depression', 'Happiness', 'Stress'],
#   'Beliefs': ['Aspirations',
#    'Internalized stigma',
#    'Locus of control',
#    'Self-efficacy',
#    'Self esteem'],
#   'Preferences': ['Time preferences', 'Risk preferences']},
#  'Behaviors': {'Economic': ['Borrowing',
#    'Consumption',
#    'Investing',
#    'Labor Supply',
#    'Occupational choice',
#    'Saving'],
#   'Health': ['Exercise', 'Food diet', 'Medication adherence'],
#   'Intergenerational': ['Educational achievement',
#    'Family interaction',
#    'Parenting'],
#   'Social': ['Crime', 'Violence']}}

# %%
study_types = [item for subcat in file['study_types'].values() for method_list in subcat.values() for item in method_list]
poverty_context = list(file['poverty_contexts'].values())
mechanisms = [item for subcat in file['mechanisms'].values() for item in subcat]
behaviors = [item for subcat in file['Behaviors'].values() for item in subcat]

# %%
import pycountry 

countries = [country.name for country in pycountry.countries]

# %%
# import pandas as pd

# excels_dict = {
# }
# excels = []

# for year in range(18, 24):
#     excel = pd.read_csv(f'data/extractedPapers20{year:02}.csv')  # Format year with leading zeros
#     excels_dict[year] = excel
#     excels.append(excel)

# %%
all_df = pd.concat(excels, ignore_index=True)

# %%
all_df.shape
# Out:
# (87257, 19)

# %%
sample_df = all_df.sample(1000, random_state=42)  
sample_df_dict = sample_df.to_dict(orient='records')

# %%
all_df_dict = all_df.to_dict(orient='records')

# %%
import time
import google.generativeai as genai
import json
import logging
import pycountry
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
import tiktoken
# from collections import defaultdict # Not used, can be removed
# import pandas as pd # Not used, can be removed

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

class GeminiModel:
    def __init__(self, api_keys, max_abstracts_per_batch=5, max_input_tokens=2000, max_output_tokens=1000, delay=2, model_name="gemma-3-27b-it", temperature=0.3,
                 retry_model_name='gemini-2.0-flash', retry_max_input_tokens=10000, retry_max_output_tokens=1000, retry_delay=5, retry_temperature=None, max_retries=10, 
                 retry_model_max_abstracts_per_batch=10):
        """
        Initializes the GeminiModel for parallel abstract classification with numeric optimizations.

        Args:
            api_keys: List of API keys or a single API key string.
            max_input_tokens: Maximum input tokens allowed per batch for initial attempts.
            max_output_tokens: Maximum output tokens allowed per batch for initial attempts.
            delay: Delay in seconds between API calls per key to manage rate limiting for initial attempts.
            model_name: Gemini model name to use for initial attempts (e.g., "gemini-2.0-flash").
            temperature: Controls the randomness of the model's output for initial attempts. Lower values (e.g., 0.1-0.3)
                         result in more deterministic output.
            retry_model_name: Model name to use for retries. If None, uses the initial model_name.
            retry_max_input_tokens: Max input tokens for retry batches. If None, uses initial max_input_tokens.
            retry_max_output_tokens: Max output tokens for retry batches. If None, uses initial max_output_tokens.
            retry_delay: Delay for retry API calls. If None, uses initial delay.
            retry_temperature: Temperature for retry API calls. If None, uses initial temperature.
            max_retries: Maximum number of retry attempts for a single API call.
        """
        # Ensure api_keys is a list
        self.api_keys = [api_keys] if isinstance(api_keys, str) else api_keys
        self.max_input_tokens = max_input_tokens
        self.max_output_tokens = max_output_tokens
        self.max_abstracts_per_batch = max_abstracts_per_batch
        self.model_name = model_name
        self.delay = delay
        self.temperature = temperature
        self.max_retries = max_retries # Max retries for _generate method

        # Retry-specific configurations
        self.retry_model_name = retry_model_name if retry_model_name is not None else self.model_name
        self.retry_max_input_tokens = retry_max_input_tokens if retry_max_input_tokens is not None else self.max_input_tokens
        self.retry_max_output_tokens = retry_max_output_tokens if retry_max_output_tokens is not None else self.max_output_tokens
        self.retry_delay = retry_delay if retry_delay is not None else self.delay
        self.retry_temperature = retry_temperature if retry_temperature is not None else self.temperature
        self.retry_model_max_abstracts_per_batch = retry_model_max_abstracts_per_batch if retry_model_max_abstracts_per_batch is not None else self.max_abstracts_per_batch


        # Initialize tiktoken encoder
        self.tokenizer = tiktoken.get_encoding("o200k_base")

        # Initialize caches and GenerativeModel instances for each API key
        self.caches = {key: {} for key in self.api_keys}
        # Initialize models for both initial and retry configurations
        self.models = {}
        for api_key in self.api_keys:
            self.models[api_key] = {
                'initial': self.model_name,
                'retry': self.retry_model_name
            }
        # Thread locks for each API key to manage per-key rate limiting
        self.locks = {key: threading.Lock() for key in self.api_keys}
        # Shared rate limit tracking across threads
        self.api_key_cooldowns = {key: 0 for key in self.api_keys} # Track cooldown end times
        self.cooldown_lock = threading.Lock()
        # Initialize label mappings; these will be populated by _create_label_mappings
        self.label_mappings = {}
        self.reverse_mappings = {}
        # Output field mappings - converts field names to numbers
        self.field_mappings = {
            'study_type': 0,
            'poverty_context': 1,
            'mechanism': 2,
            'behavior': 3
        }
        self.reverse_field_mappings = {v: k for k, v in self.field_mappings.items()}
        # Pre-calculate token overhead for the static part of the prompt
        self.base_prompt_tokens = self._calculate_base_prompt_tokens()
        logger.info(f"Base prompt token overhead: {self.base_prompt_tokens} tokens")
        logger.info(f"Initialized with {len(self.api_keys)} API keys for parallel processing")

    def _calculate_base_prompt_tokens(self) -> int:
        """
        Calculates the token count of the static part of the prompt using tiktoken.
        This helps in determining how many abstract tokens can fit into a batch.
        """
        # Generate a prompt with an empty abstracts_batch to get the base prompt size
        # This includes all instructions and label mappings but no abstract content.
        dummy_abstracts_batch = {}
        # Dummy data for prompt creation to ensure all static parts are counted
        study_types = ["Type A"]
        poverty_contexts = ["Context X"]
        mechanisms = ["Mechanism M"]
        behaviors = ["Behavior P"]

        base_prompt = self._create_prompt(
            dummy_abstracts_batch, study_types, poverty_contexts, mechanisms, behaviors
        )
        return len(self.tokenizer.encode(base_prompt))

    def _count_tokens(self, text: str) -> int:
        """
        Counts tokens for a given text using tiktoken.
        """
        return len(self.tokenizer.encode(text))

    def _estimate_output_tokens(self, num_abstracts: int) -> int:
        """
        Estimates the output token count for a given number of abstracts.
        Based on the optimized JSON structure with numeric keys and DOI mappings.
        """
        # Optimized structure: {"0": {"0": [999], "1": [999], "2": [999], "3": [999]}}
        # Numeric DOI (1-3 digits) + numeric field keys (1 digit) + values (1-3 digits each)
        # Plus JSON formatting characters
        tokens_per_abstract = 20
        # Array wrapper tokens
        array_overhead = 10
        return (num_abstracts * tokens_per_abstract) + array_overhead

    def _create_label_mappings(self, study_types: list, poverty_contexts: list, mechanisms: list, behaviors: list):
        """
        Creates numeric mappings for all label categories.
        These mappings are used in the prompt and for decoding results.
        """
        self.label_mappings = {
            'study_type': {label: i for i, label in enumerate(study_types)},
            'poverty_context': {label: i for i, label in enumerate(poverty_contexts)},
            'mechanism': {label: i for i, label in enumerate(mechanisms)},
            'behavior': {label: i for i, label in enumerate(behaviors)}
        }
        # Add a special code for "Insufficient info" for all categories
        insufficient_code = 999
        for category in self.label_mappings:
            self.label_mappings[category]["Insufficient info"] = insufficient_code
        # Create reverse mappings for decoding numeric codes back to text labels
        self.reverse_mappings = {
            category: {num: label for label, num in mapping.items()}
            for category, mapping in self.label_mappings.items()
        }

    def _create_doi_mapping(self, abstracts_batch: dict) -> tuple[dict, dict]:
        """
        Creates numeric mapping for DOIs in current batch to save tokens.
        """
        doi_to_num = {doi: i for i, doi in enumerate(abstracts_batch.keys())}
        num_to_doi = {i: doi for doi, i in doi_to_num.items()}
        return doi_to_num, num_to_doi
    
    def _get_available_api_keys(self) -> list:
        """
        Returns list of API keys not currently in cooldown.
        """
        with self.cooldown_lock:
            current_time = time.time()
            return [key for key in self.api_keys if current_time >= self.api_key_cooldowns[key]]

    def _generate(self, prompt: str, api_key: str, attempt_type: str = 'initial') -> str:
        """
        Generates content using a specific API key with comprehensive retry logic.
        Uses model and parameters based on `attempt_type` ('initial' or 'retry').
        """
        cache = self.caches[api_key]
        if prompt in cache:
            return cache[prompt]

        # Determine which model and parameters to use based on attempt_type
        model_name = self.models[api_key][attempt_type]
        current_delay = self.delay if attempt_type == 'initial' else self.retry_delay
        current_temperature = self.temperature if attempt_type == 'initial' else self.retry_temperature
        current_max_retries = self.max_retries

        # Use lock to ensure rate limiting per API key AND fix race condition
        with self.locks[api_key]:
            # Check cooldown INSIDE the API key lock to prevent race conditions
            with self.cooldown_lock:
                current_time = time.time()
                if current_time < self.api_key_cooldowns[api_key]:
                    cooldown_remaining = self.api_key_cooldowns[api_key] - current_time
                    logger.info(f"API key {api_key[:6]}... is in cooldown. Waiting for {cooldown_remaining:.2f} seconds.")
                    time.sleep(cooldown_remaining)

            # Configure API key for this specific request (fixes the global configuration issue)
            genai.configure(api_key=api_key)
            
            # Create model instance with the correct configuration
            model_instance = genai.GenerativeModel(model_name)
            
            for attempt in range(current_max_retries):
                try:
                    time.sleep(current_delay)  # Rate limit management
                    generation_config = {
                        "temperature": current_temperature,
                    }
                    response = model_instance.generate_content(
                        prompt,
                        generation_config=generation_config
                    )
                    output = response.text
                    cache[prompt] = output
                    return output
                    
                except Exception as e:
                    # More robust error handling for different types of rate limiting
                    is_rate_limited = False
                    retry_seconds = 10  # Default fallback
                    
                    # Check for rate limiting in various ways the API might indicate it
                    if hasattr(e, 'status_code') and e.status_code == 429:
                        is_rate_limited = True
                    elif hasattr(e, 'retry_delay'):
                        is_rate_limited = True
                        if hasattr(e.retry_delay, 'seconds'):
                            retry_seconds = e.retry_delay.seconds
                        else:
                            retry_seconds = e.retry_delay
                    elif 'rate limit' in str(e).lower() or 'quota' in str(e).lower():
                        is_rate_limited = True
                    
                    if is_rate_limited:
                        logger.warning(f"Rate limited on attempt {attempt + 1} ({attempt_type}) with API key {api_key[:6]}... Waiting {retry_seconds} seconds...")
                        with self.cooldown_lock:
                            self.api_key_cooldowns[api_key] = time.time() + retry_seconds
                        time.sleep(retry_seconds)
                    else:
                        logger.error(f"Error on attempt {attempt + 1} ({attempt_type}) with API key {api_key[:6]}...: {e}")
                    
                    if attempt == current_max_retries - 1:
                        raise e  # Re-raise if all retries are exhausted
                
    def _create_prompt(self, abstracts_batch: dict, study_types: list, poverty_contexts: list, mechanisms: list, behaviors: list) -> str:
        """
        Creates a prompt for the Gemini model to process a batch of abstracts,
        including instructions and numeric mappings for both DOIs and field keys.
        """
        doi_to_num, num_to_doi = self._create_doi_mapping(abstracts_batch)

        formatted_abstracts = ""
        for doi, abstract in abstracts_batch.items():
            numeric_id = doi_to_num[doi]
            formatted_abstracts += f"ID: {numeric_id}\nAbstract: {abstract}\n\n"

        study_type_mapping = "\n".join([f"{i}: {label}" for i, label in enumerate(study_types)])
        poverty_context_mapping = "\n".join([f"{i}: {label}" for i, label in enumerate(poverty_contexts)])
        mechanism_mapping = "\n".join([f"{i}: {label}" for i, label in enumerate(mechanisms)])
        behavior_mapping = "\n".join([f"{i}: {label}" for i, label in enumerate(behaviors)])

        prompt = f"""
You will analyze {len(abstracts_batch)} research abstracts. For each abstract, assign numeric codes in the following four categories:

**Field Key Mappings:**
0: Study Type (can assign multiple numbers if applicable)
1: Poverty Context (can assign multiple numbers if applicable)
2: Mechanism (can assign multiple numbers if applicable)
3: Behavior (can assign multiple numbers if applicable)

**Critical Instructions:**
- You must assign **at least one** numeric code for **each** of the four fields (0–3).
- Use ONLY the numeric codes provided below for all categories.
- Assign multiple codes if the abstract supports more than one. Format as: `[1, 3, 5]`. A single label may be written as `2` or `[2]`.
- Do **not** leave any field blank. Return a full set of labels for every abstract.

**On Using '999' (Insufficient Info):**
- Use code `999` **only if no reasonable inference is possible** after full consideration of the abstract and plausible background knowledge.
- You are expected to **infer beyond the literal abstract** where appropriate, based on:
    - Field knowledge
    - The study setting or goals
    - Known practices in similar research

**Labeling Guidance by Category:**
- **Study Type:** Infer from references to interventions, design, or data (e.g., control group implies experiment).
- **Poverty Context:** Infer from setting, economic indicators, demographic focus, or target population.
- **Mechanisms:** Identify cognitive, psychological, or behavioral processes mentioned or implied.
- **Behavior:** Identify actions, decisions, or patterns studied or influenced.

**Numeric Label Codes:**

**Study Type Codes (Field 0):** {study_type_mapping}
999: Insufficient info

**Poverty Context Codes (Field 1):** {poverty_context_mapping}
999: Insufficient info

**Mechanism Codes (Field 2):** {mechanism_mapping}
999: Insufficient info

**Behavior Codes (Field 3):** {behavior_mapping}
999: Insufficient info

**Input Abstracts:** {formatted_abstracts}

**IMPORTANT:** Return a valid JSON array. Each entry must include all four fields (0, 1, 2, 3), with one or more numeric codes per field.

**Output Format Example:**
[
{{"0": [0, 2], "1": [1], "2": [2, 4], "3": [3]}},
{{"0": [1], "1": [0], "2": [5], "3": [2]}}
]
"""
        return prompt

    def _parse_json_response(self, json_str_to_parse: str, api_key_snippet: str, doi_mapping: dict) -> dict:
        """
        Robustly parses a JSON string response from the Gemini model, handling the array format
        and converting numeric DOI/field keys back to original format.
        Uses simplified JSON extraction approach.
        """
        numeric_results = {}
        parsed_json = None
        try:
            # Try direct JSON parsing first
            parsed_json = json.loads(json_str_to_parse)
            logger.info("Successfully parsed JSON directly.")
        except json.JSONDecodeError as e:
            # Use the simpler extraction method from the second version
            start_idx = json_str_to_parse.find('{')
            if json_str_to_parse.find('[') >= 0 and (start_idx == -1 or json_str_to_parse.find('[') < start_idx):
                # Array format detected
                start_idx = json_str_to_parse.find('[')
                end_idx = json_str_to_parse.rfind(']') + 1
            else:
                # Object format
                end_idx = json_str_to_parse.rfind('}') + 1
            if start_idx >= 0 and end_idx > start_idx:
                json_str_extracted = json_str_to_parse[start_idx:end_idx]
                try:
                    parsed_json = json.loads(json_str_extracted)
                    logger.info("Successfully parsed JSON after extraction.")
                except json.JSONDecodeError as e_extract:
                    raise ValueError(f"Could not extract valid JSON from response for API key {api_key_snippet}: {e_extract}")
            else:
                raise ValueError(f"Could not find valid JSON object in response for API key {api_key_snippet}")

        # Convert array format to flat dictionary or handle nested format
        if isinstance(parsed_json, list):
            # Handle array format where each item corresponds to a DOI by index
            for idx, fields in enumerate(parsed_json):
                if isinstance(fields, dict):
                    numeric_results[str(idx)] = fields
        elif isinstance(parsed_json, dict):
            # Handle nested format directly
            numeric_results = parsed_json
        else:
            raise ValueError(f"Unexpected JSON structure: {type(parsed_json)}")

        # Convert numeric DOI and field keys back to original format
        converted_results = {}
        for numeric_doi, fields in numeric_results.items():
            # Convert numeric DOI back to original DOI
            try:
                numeric_doi_int = int(numeric_doi)
                original_doi = doi_mapping[numeric_doi_int]
            except (ValueError, KeyError):
                logger.warning(f"Could not map numeric DOI {numeric_doi} back to original DOI")
                continue

            # Convert numeric field keys back to original field names
            converted_fields = {}
            for numeric_field, values in fields.items():
                try:
                    numeric_field_int = int(numeric_field)
                    original_field = self.reverse_field_mappings[numeric_field_int]
                    converted_fields[original_field] = values
                except (ValueError, KeyError):
                    logger.warning(f"Could not map numeric field {numeric_field} back to original field name")
                    continue
            converted_results[original_doi] = converted_fields
        return converted_results

    def _decode_numeric_labels(self, numeric_results: dict) -> tuple[dict, dict]:
        """
        Converts numeric codes in the classification results back to text labels.
        Handles both single numeric values and lists of numeric values.
        Returns decoded results and a dictionary of papers with invalid codes.
        """
        decoded_results = {}
        invalid_papers = {} # Track papers with invalid codes
        for doi, labels in numeric_results.items():
            decoded_labels = {}
            has_invalid_code = False
            # Decode each category
            for category in ['study_type', 'poverty_context', 'mechanism', 'behavior']:
                if category in labels:
                    numeric_codes = labels[category]
                    # Ensure numeric_codes is iterable (handle single int vs list)
                    code_list = [numeric_codes] if not isinstance(numeric_codes, list) else numeric_codes
                    # Decode each numeric code to text
                    decoded_texts = []
                    for code in code_list:
                        if code in self.reverse_mappings[category]:
                            decoded_texts.append(self.reverse_mappings[category][code])
                        else:
                            logger.warning(f"Invalid numeric code {code} for category {category} in DOI {doi}")
                            has_invalid_code = True
                            break # Break from inner loop on first invalid code
                    if has_invalid_code:
                        break # Break from outer loop if an invalid code was found
                    # Join multiple labels with comma or return single label
                    decoded_labels[category] = ", ".join(decoded_texts) if len(decoded_texts) > 1 else (decoded_texts[0] if decoded_texts else "Insufficient info")
                else:
                    # If category is missing in the model's response, mark as insufficient
                    decoded_labels[category] = "Insufficient info"

            if has_invalid_code:
                invalid_papers[doi] = labels # Store original numeric labels for failed papers
            else:
                decoded_results[doi] = decoded_labels
        return decoded_results, invalid_papers

    def _process_batch_with_key(self, batch_data: tuple, attempt_type: str = 'initial') -> tuple[dict, dict]:
        """
        Processes a single batch of abstracts using an assigned API key.
        Handles API calls, JSON parsing, and decoding of numeric labels.
        Returns successfully decoded results and any abstracts that failed.
        `attempt_type` specifies if it's an 'initial' call or a 'retry'.
        """
        batch, api_key, study_types, poverty_contexts, mechanisms, behaviors = batch_data
        try:
            # Create DOI mapping for this batch
            doi_to_num, num_to_doi = self._create_doi_mapping(batch)
            # Generate classification response from the model
            batch_raw_response = self._generate(
                self._create_prompt(batch, study_types, poverty_contexts, mechanisms, behaviors),
                api_key,
                attempt_type=attempt_type # Pass the attempt type
            )
            logger.info(f"Successfully classified batch of {len(batch)} abstracts using API key: {api_key[:6]}... ({attempt_type} attempt)")
            # Robustly parse the JSON response with DOI mapping
            numeric_results = self._parse_json_response(batch_raw_response, api_key + '...', num_to_doi)
            # Decode numeric codes back to text labels
            decoded_results, invalid_papers = self._decode_numeric_labels(numeric_results)
            # Determine which papers from the current batch successfully processed
            failed_abstracts = {doi: batch[doi] for doi in batch if doi not in decoded_results}
            return decoded_results, failed_abstracts
        except Exception as e:
            logger.error(f"Error processing batch with API key {api_key[:6]}... ({attempt_type} attempt): {e}")
            return {}, batch # If any error, assume all papers in batch failed

    def _create_abstract_batches(self, all_abstracts: dict, categories: tuple, max_input_tokens: int, max_output_tokens: int, max_abstracts_per_batch: int = None) -> list:
        """
        Generates batches of abstracts, ensuring each batch respects both input and output token limits.
        Assigns API keys in a round-robin fashion to each batch.
        Now accounts for optimized token usage with numeric DOIs and field keys.

        Args:
            all_abstracts: Dictionary of all abstracts {doi: abstract_text}.
            categories: Tuple of (study_types, poverty_contexts, mechanisms, behaviors).
            max_input_tokens: The maximum input token count allowed per batch.
            max_output_tokens: The maximum output token count allowed per batch.
            max_abstracts_per_batch: Optional, maximum number of abstracts per batch.

        Returns:
            A list of tuples, where each tuple is (abstracts_batch_dict, api_key, *categories).
        """
        study_types, poverty_contexts, mechanisms, behaviors = categories
        batches = []
        current_batch_abstracts = {}
        current_batch_input_tokens = self.base_prompt_tokens # Start with the prompt's fixed overhead
        abstracts_items = list(all_abstracts.items())

        for doi, abstract in abstracts_items:
            # For token counting, use optimized format (numeric ID instead of full DOI)
            numeric_id = len(current_batch_abstracts) # Approximate numeric ID
            abstract_content_for_prompt = f"ID: {numeric_id}\nAbstract: {abstract}\n\n"
            abstract_tokens = self._count_tokens(abstract_content_for_prompt)

            # Estimate output tokens for current batch size + 1
            estimated_output_tokens = self._estimate_output_tokens(len(current_batch_abstracts) + 1)

            # Calculate new input tokens
            new_input_tokens = current_batch_input_tokens + abstract_tokens

            # Check if adding this abstract exceeds either input or output token limits, or abstract count limit
            if (new_input_tokens > max_input_tokens or
                estimated_output_tokens > max_output_tokens or
                (self.max_abstracts_per_batch and len(current_batch_abstracts) >= self.max_abstracts_per_batch)):
                if current_batch_abstracts: # Only add if the batch is not empty
                    api_key = self.api_keys[len(batches) % len(self.api_keys)] # Round-robin API key
                    batches.append((current_batch_abstracts, api_key, *categories))
                # Start a new batch with the current abstract
                current_batch_abstracts = {doi: abstract}
                current_batch_input_tokens = self.base_prompt_tokens + abstract_tokens
            else:
                # Add abstract to the current batch
                current_batch_abstracts[doi] = abstract
                current_batch_input_tokens = new_input_tokens

        # Add any remaining abstracts in the last batch
        if current_batch_abstracts:
            available_keys = self._get_available_api_keys()
            if not available_keys:
                available_keys = self.api_keys # Fallback to all keys if none available
            api_key = available_keys[len(batches) % len(available_keys)]
            batches.append((current_batch_abstracts, api_key, *categories))

        return batches

    def _retry_failed_papers(self, failed_abstracts: dict, categories: tuple, max_retry_attempts: int = 3) -> dict:
        """
        Retries processing abstracts that failed initial classification.
        Uses retry-specific model, token limits, and delay.
        """
        successfully_processed_retries = {}
        retries_remaining = max_retry_attempts

        while failed_abstracts and retries_remaining > 0:
            retries_remaining -= 1
            logger.info(f"Retry attempt for {len(failed_abstracts)} papers. {retries_remaining} attempts remaining.")

            # Create retry batches using retry-specific configurations
            retry_batches = self._create_abstract_batches(
                failed_abstracts, categories, self.retry_max_input_tokens, self.retry_max_output_tokens,
                max_abstracts_per_batch= self.retry_model_max_abstracts_per_batch 
            )
            logger.info(f"Created {len(retry_batches)} retry batches using retry configurations.")

            with ThreadPoolExecutor(max_workers=len(self.api_keys)) as executor:
                future_to_batch = {executor.submit(self._process_batch_with_key, batch_data, 'retry'): batch_data[0]
                                   for batch_data in retry_batches}

                for future in as_completed(future_to_batch):
                    try:
                        decoded_results, batch_failed_on_retry = future.result()
                        successfully_processed_retries.update(decoded_results)
                        # Remove successfully processed papers from the `failed_abstracts` list
                        for doi in decoded_results:
                            failed_abstracts.pop(doi, None)
                    except Exception as e:
                        logger.error(f"Error in retry batch: {e}")

            if failed_abstracts and retries_remaining > 0:
                # Exponential backoff between retry rounds
                wait_time = self.retry_delay * (max_retry_attempts - retries_remaining)
                logger.info(f"Waiting for {wait_time:.2f} seconds before next retry round.")
                time.sleep(wait_time)

        return successfully_processed_retries

    def _validate_and_fix_labels(self, labels_dict: dict, doi: str) -> dict:
        """
        Validates that all required classification fields are present for a given DOI
        and fills in "Insufficient info" for any missing fields.
        """
        required_fields = ['study_type', 'poverty_context', 'mechanism', 'behavior']
        if doi not in labels_dict:
            logger.warning(f"DOI {doi} not found in classification results, providing default 'Insufficient info' for all fields.")
            return {field: "Insufficient info" for field in required_fields}
        result = labels_dict[doi]
        # Check if all required fields are present and fix missing ones
        for field in required_fields:
            if field not in result or result[field] is None or (isinstance(result[field], str) and result[field].strip() == ""):
                logger.warning(f"Missing or empty field '{field}' for DOI {doi}, setting to 'Insufficient info'")
                result[field] = "Insufficient info"
        return result

    def classify(self, papers: list, study_types: list, poverty_contexts: list, mechanisms: list, behaviors: list, max_papers_to_classify: int = None) -> list:
        """
        Classifies a list of research abstracts using parallel processing with multiple API keys,
        batching based on token limits. Includes retry mechanism for failed classifications.
        Uses numeric optimizations for DOIs and field keys to save tokens.

        Args:
            papers: List of paper dictionaries, each containing 'doi' and 'abstract'.
            study_types: List of study type definitions.
            poverty_contexts: List of poverty context definitions.
            mechanisms: List of mechanism definitions.
            behaviors: List of behavior definitions.
            max_papers_to_classify: Optional. If provided, limits the classification to this many papers.
                                    The papers will be taken from the beginning of the `papers` list.
            max_abstracts_per_batch: Optional. If provided, limits the number of abstracts in each batch.

        Returns:
            List of paper dictionaries updated with classification results.
        """
        # Store categories for consistent access
        categories = (study_types, poverty_contexts, mechanisms, behaviors)

        # Create label mappings first, as they are needed for decoding
        self._create_label_mappings(*categories)

        # Filter valid abstracts from the input papers
        all_abstracts = {p['doi']: p['abstract'] for p in papers if 'doi' in p and 'abstract' in p and p['abstract']}
        if not all_abstracts:
            logger.warning("No valid abstracts found in input papers.")
            return papers

        # Apply the total classification limit if specified
        if max_papers_to_classify is not None and max_papers_to_classify > 0:
            original_abstracts_count = len(all_abstracts)
            # Create a new dictionary with only the limited number of abstracts
            limited_abstracts = {}
            for i, (doi, abstract) in enumerate(all_abstracts.items()):
                if i >= max_papers_to_classify:
                    break
                limited_abstracts[doi] = abstract
            all_abstracts = limited_abstracts
            if len(all_abstracts) < original_abstracts_count:
                logger.info(f"Limiting total classification to {len(all_abstracts)} papers out of {original_abstracts_count} available.")


        logger.info(f"Starting classification for {len(all_abstracts)} abstracts...")
        # Initial batch creation, now respecting max_abstracts_per_batch
        batches = self._create_abstract_batches(
            all_abstracts, categories, self.max_input_tokens, self.max_output_tokens, self.max_abstracts_per_batch # Use self.max_abstracts_per_batch for consistency if not overridden
        )
        logger.info(f"Created {len(batches)} initial batches for classification.")
        final_results = {}
        failed_abstracts_initial = {}

        # Process batches in parallel
        with ThreadPoolExecutor(max_workers=len(self.api_keys)) as executor:
            future_to_batch = {executor.submit(self._process_batch_with_key, batch_data, 'initial'): batch_data[0]
                               for batch_data in batches}
            for future in as_completed(future_to_batch):
                try:
                    decoded_results, batch_failed = future.result()
                    final_results.update(decoded_results)
                    failed_abstracts_initial.update(batch_failed) # Collect abstracts that failed this batch
                except Exception as e:
                    logger.error(f"Error in main batch processing: {e}")

        # Retry failed abstracts
        if failed_abstracts_initial:
            logger.info(f"Attempting to retry {len(failed_abstracts_initial)} failed abstracts.")
            successfully_retried = self._retry_failed_papers(failed_abstracts_initial, categories, max_retry_attempts=3)
            final_results.update(successfully_retried)

        # Prepare final output: update original papers with classification results
        classified_papers = []
        for p in papers:
            doi = p.get('doi')
            if doi and doi in all_abstracts: # Only process papers that were part of the initial classification set
                # Validate and fix labels for each paper
                validated_labels = self._validate_and_fix_labels(final_results, doi)
                p.update(validated_labels)
            else:
                # If a paper wasn't processed (e.g., no abstract or not in limited set),
                # ensure it still has the classification fields with "Insufficient info"
                for field in ['study_type', 'poverty_context', 'mechanism', 'behavior']:
                    if field not in p:
                        p[field] = "Insufficient info"
            classified_papers.append(p)

        return classified_papers

# %%
excels_dict.keys()
# Out:
# dict_keys([18, 19, 20, 21, 22, 23])

# %%
# dict_to_process = excels_dict[5].to_dict(orient='records')

# %%
import re
import pycountry
from typing import List, Dict, Set
import spacy
from collections import Counter

class FastCountryExtractor:
    """
    Fast country extraction using multiple methods for research abstracts.
    """
    
    def __init__(self):
        """Initialize the country extractor with various lookup methods."""
        self.country_patterns = self._build_country_patterns()
        self.city_to_country = self._build_city_mappings()
        
        # Try to load spaCy model (optional, fallback to regex if not available)
        try:
            self.nlp = spacy.load("en_core_web_sm")
            self.use_spacy = True
        except OSError:
            print("Warning: spaCy model not found. Using regex-only approach.")
            self.nlp = None
            self.use_spacy = False
    
    def _build_country_patterns(self) -> Dict[str, str]:
        """Build comprehensive country name patterns including variations."""
        patterns = {}
        
        for country in pycountry.countries:
            # Official name from pycountry
            patterns[country.name.lower()] = country.name
            
            # Add official_name if available
            if hasattr(country, 'official_name') and country.official_name:
                patterns[country.official_name.lower()] = country.name
            
            # Add alpha codes as text variations  
            patterns[country.alpha_2.lower()] = country.name
            patterns[country.alpha_3.lower()] = country.name
        
        # Manual variations that pycountry doesn't provide
        # These are common informal names found in research papers
        manual_variations = {
            'united states': ['usa', 'us', 'america', 'united states of america'],
            'united kingdom': ['uk', 'britain', 'great britain', 'england', 'scotland', 'wales', 'northern ireland'],
            'south korea': ['korea', 'republic of korea', 'south korea'],
            'north korea': ['dprk', 'democratic people\'s republic of korea'],
            'russia': ['russian federation', 'ussr', 'soviet union'],
            'iran': ['islamic republic of iran', 'persia'],
            'vietnam': ['viet nam'],
            'czech republic': ['czechia', 'czechoslovakia'],
            'democratic republic of the congo': ['drc', 'congo', 'zaire'],
            'republic of the congo': ['congo-brazzaville'],
            'ivory coast': ['côte d\'ivoire'],
            'bosnia and herzegovina': ['bosnia'],
            'trinidad and tobago': ['trinidad'],
            'antigua and barbuda': ['antigua'],
            'saint vincent and the grenadines': ['saint vincent'],
            'sao tome and principe': ['sao tome'],
            'myanmar': ['burma'],
            'netherlands': ['holland'],
            'switzerland': ['swiss confederation'],
            'vatican city': ['holy see'],
        }
        
        # Add manual variations to patterns
        for standard_name, variations in manual_variations.items():
            for variant in variations:
                patterns[variant.lower()] = self._get_standard_country_name(standard_name)
        
        return patterns
    
    def _get_standard_country_name(self, country_name_lower: str) -> str:
        """Get the standard pycountry name for a country."""
        # Try to find the country in pycountry
        for country in pycountry.countries:
            if country.name.lower() == country_name_lower:
                return country.name
        
        # Fallback to title case if not found
        return country_name_lower.title()
    
    def _build_city_mappings(self) -> Dict[str, str]:
        """Build mappings from major cities to countries."""
        # This is a simplified version - in practice, you'd want a comprehensive database
        city_mappings = {
            # Major cities that frequently appear in research
            'new york': 'United States',
            'los angeles': 'United States',
            'chicago': 'United States',
            'boston': 'United States',
            'washington': 'United States',
            'london': 'United Kingdom',
            'manchester': 'United Kingdom',
            'birmingham': 'United Kingdom',
            'paris': 'France',
            'lyon': 'France',
            'marseille': 'France',
            'berlin': 'Germany',
            'munich': 'Germany',
            'hamburg': 'Germany',
            'tokyo': 'Japan',
            'osaka': 'Japan',
            'kyoto': 'Japan',
            'beijing': 'China',
            'shanghai': 'China',
            'guangzhou': 'China',
            'delhi': 'India',
            'mumbai': 'India',
            'bangalore': 'India',
            'kolkata': 'India',
            'toronto': 'Canada',
            'vancouver': 'Canada',
            'montreal': 'Canada',
            'sydney': 'Australia',
            'melbourne': 'Australia',
            'brisbane': 'Australia',
            'seoul': 'South Korea',
            'moscow': 'Russia',
            'st petersburg': 'Russia',
            'cairo': 'Egypt',
            'nairobi': 'Kenya',
            'lagos': 'Nigeria',
            'cape town': 'South Africa',
            'johannesburg': 'South Africa',
            'sao paulo': 'Brazil',
            'rio de janeiro': 'Brazil',
            'mexico city': 'Mexico',
            'buenos aires': 'Argentina',
        }
        return city_mappings
    
    def extract_countries_regex(self, text: str) -> List[str]:
        """Extract countries using regex pattern matching."""
        text_lower = text.lower()
        found_countries = set()
        
        # Look for country patterns
        for pattern, country_name in self.country_patterns.items():
            if re.search(r'\b' + re.escape(pattern) + r'\b', text_lower):
                found_countries.add(country_name)
        
        # Look for city patterns
        for city, country in self.city_to_country.items():
            if re.search(r'\b' + re.escape(city) + r'\b', text_lower):
                found_countries.add(country)
        
        return list(found_countries)
    
    def extract_countries_spacy(self, text: str) -> List[str]:
        """Extract countries using spaCy NER."""
        if not self.use_spacy:
            return []
        
        doc = self.nlp(text)
        found_countries = set()
        
        for ent in doc.ents:
            if ent.label_ in ['GPE', 'LOC']:  # Geopolitical entity or location
                entity_text = ent.text.lower()
                if entity_text in self.country_patterns:
                    found_countries.add(self.country_patterns[entity_text])
                elif entity_text in self.city_to_country:
                    found_countries.add(self.city_to_country[entity_text])
        
        return list(found_countries)
    
    def extract_countries_combined(self, text: str) -> List[str]:
        """Combine regex and spaCy approaches for best results."""
        countries_regex = self.extract_countries_regex(text)
        countries_spacy = self.extract_countries_spacy(text) if self.use_spacy else []
        
        # Combine and deduplicate
        all_countries = list(set(countries_regex + countries_spacy))
        
        return all_countries
    
    def extract_from_abstract(self, abstract: str, method: str = 'combined') -> str:
        """
        Extract countries from research abstract and return as comma-separated string.
        
        Args:
            abstract: The research abstract text
            method: 'regex', 'spacy', or 'combined'
        
        Returns:
            Comma-separated country names or "Insufficient info"
        """
        if method == 'regex':
            countries = self.extract_countries_regex(abstract)
        elif method == 'spacy':
            countries = self.extract_countries_spacy(abstract)
        else:
            countries = self.extract_countries_combined(abstract)
        
        if countries:
            return ', '.join(sorted(countries))
        else:
            return "Insufficient info"

# %%
def create_country_extractor_function(method='combined'):
    """
    Creates a function optimized for pandas .apply() operations.
    
    Args:
        method: 'regex', 'spacy', or 'combined'
    
    Returns:
        Function that can be used with df['column'].apply()
    """
    # Initialize extractor once (important for performance!)
    extractor = FastCountryExtractor()
    
    def extract_countries_from_text(text):
        """Function optimized for pandas apply."""
        if pd.isna(text) or not isinstance(text, str) or not text.strip():
            return "Insufficient info"
        
        return extractor.extract_from_abstract(text, method=method)
    
    return extract_countries_from_text

# country_name_extractor = FastCountryExtractor()
# dict_to_process_df_testing = pd.DataFrame(dict_to_process)
# country_extractor_func = create_country_extractor_function(method='combined')
# dict_to_process_df_testing['country_of_study'] = dict_to_process_df_testing['abstract'].apply(country_extractor_func)

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Fetch API key from environment variables
api_key = os.getenv("GEMINI_API_KEY")

# Load Google Sheets credentials from environment variables
type= os.getenv("type")
project_id = os.getenv("project_id")
private_key_id = os.getenv("private_key_id") 
private_key = os.getenv("private_key").replace("\\n", "\n")  
client_email = os.getenv("client_email")
client_id = os.getenv("client_id")
auth_uri = os.getenv("auth_uri")
token_uri = os.getenv("token_uri")
auth_provider_x509_cert_url = os.getenv("auth_provider_x509_cert_url")
client_x509_cert_url= os.getenv("client_x509_cert_url")
universe_domain= os.getenv("universe_domain")
credenetials = {
    "type": type,
    "project_id": project_id,
    "private_key_id": private_key_id,
    "private_key": private_key,
    "client_email": client_email,
    "client_id": client_id,
    "auth_uri": auth_uri,
    "token_uri": token_uri,
    "auth_provider_x509_cert_url": auth_provider_x509_cert_url,
    "client_x509_cert_url": client_x509_cert_url,
    "universe_domain": universe_domain
}
# Load Google Sheets IDs from environment variables
papers_spreadsheet_id = os.getenv("papers_spreadsheet_id")
density = os.getenv("density")
density_X = os.getenv("X")
density_Y = os.getenv("Y")
topics_spreadsheet_id = os.getenv("topics_spreadsheet_id")
spreadsheet_id =  {
    "papers": papers_spreadsheet_id,
    "density": density,
    "density_X": density_X,
    "density_Y": density_Y,
    "topics": topics_spreadsheet_id
}

# %%
from data import googleSheets
import importlib

importlib.reload(googleSheets)

google_sheets = googleSheets.API(credentials_json=credenetials)

# # Upload the results DataFrame to Google Sheets
# google_sheets.replace(
#     results_df, 
#     spreadsheet_id=spreadsheet_id['papers'], 
#     sheet_name='Sheet1'
#     )
# Out:
# 2025-06-20 00:11:57,413 - INFO - Initializing Google Sheets API
# 2025-06-20 00:11:57,414 - INFO - Building Google Sheets service
# 2025-06-20 00:11:57,473 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2025-06-20 00:11:57,477 - INFO - Google Sheets service built successfully
# 2025-06-20 00:11:57,477 - INFO - API initialized with batch size: 1000

# %%
# https://docs.google.com/spreadsheets/d/1EMG3n3Ywt1X4Y-Z5eQCxyrZNA9Yzx00ALUe2HjsdeAQ/edit?gid=0#gid=0

# %%
import pandas as pd

classifier = GeminiModel(
    api_keys=[
'AIzaSyA3nUJg48V7qtKShrBmoXCZxe_kkJq0boA',
'AIzaSyDpLNLD65KEkp8-jXLpemwCidvKx5Pq7OE',
'AIzaSyD8NGIMPELnLoBw1VxdvzuM7_6M9WA6_00',
              ])


df = pd.read_csv('data/extractedPapers2024.csv')
df.dropna(subset=['abstract', 'doi'], inplace=True)
df_dict = df.groupby('year').apply(lambda x: x[['doi', 'abstract']]).to_dict(orient='index')
classified = classifier.classify(
    df_dict,
    study_types=study_types,
    poverty_contexts=poverty_context,
    mechanisms=mechanisms,
    behaviors=behaviors ) 
classified_df = pd.DataFrame(classified)
country_extractor_func = create_country_extractor_function(method='spacy')
classified_df['country_of_study'] = classified_df['abstract'].apply(country_extractor_func)
classified_df.to_csv('data/classified_results_2024.csv', index=False)



# classified_results = []

# for key, value in excels_dict.items():

#     if key <= 22:
#         continue
#     print(f"Processing ex el year: {key}")
#     value_df = value
#     # drop missing values in 'abstract' and 'doi' columns
#     value_df = value_df.dropna(subset=['abstract', 'doi'])
#     value_dict = value_df.to_dict(orient='records')
#     classified_results = classifier.classify(
#         value_dict,
#         study_types=study_types,
#         poverty_contexts=poverty_context,
#         mechanisms=mechanisms,
#         behaviors=behaviors
#                 )
#     classified_results_df = pd.DataFrame(classified_results)
#     country_extractor_func = create_country_extractor_function(method='spacy')
#     classified_results_df['country_of_study'] = classified_results_df['abstract'].apply(country_extractor_func)
#     # Upload the results DataFrame to Google Sheets
#     google_sheets.append(
#         classified_results_df, 
#         spreadsheet_id='1EMG3n3Ywt1X4Y-Z5eQCxyrZNA9Yzx00ALUe2HjsdeAQ', 
#     )

#     classified_results.append(classified_results_df)
#     classified_results_df.to_csv(f'data/classified_results_{key}.csv', index=False)
# Out:
# 2025-06-20 00:11:58,829 - INFO - Base prompt token overhead: 538 tokens
# 2025-06-20 00:11:58,831 - INFO - Initialized with 3 API keys for parallel processing
# 2025-06-20 00:11:58,969 - INFO - Starting classification for 10131 abstracts...
# Processing ex el year: 23
# 2025-06-20 00:12:01,448 - INFO - Created 2481 initial batches for classification.
# 2025-06-20 00:12:08,390 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:12:08,394 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:12:08,932 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:12:08,933 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:12:09,521 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:12:09,532 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:12:15,424 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:12:15,425 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:12:15,426 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:12:15,426 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:12:16,556 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:12:16,560 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:12:18,695 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:12:18,889 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:12:19,416 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:12:19,416 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:12:30,785 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:12:30,986 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:12:42,901 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:12:43,093 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:12:55,050 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:12:55,203 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:13:10,218 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:13:10,221 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:13:11,961 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:13:11,967 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:13:17,328 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:13:17,331 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:13:18,808 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:13:18,810 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:13:19,640 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:13:19,643 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:13:21,787 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:13:21,802 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:13:25,586 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:13:25,588 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:13:33,950 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:13:33,951 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:13:46,045 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:13:46,050 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:13:58,124 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:13:58,168 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:14:14,883 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:14:14,885 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:14:15,289 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:14:15,292 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:14:21,024 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:14:21,029 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:14:21,168 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:14:21,169 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:14:21,391 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:14:21,393 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:14:21,394 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1016/s2542-5196(23)00089-x
# 2025-06-20 00:14:21,395 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1257/app.20220073
# 2025-06-20 00:14:23,506 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:14:23,673 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:14:27,014 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:14:27,017 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:14:35,618 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:14:35,803 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:14:47,762 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:14:47,932 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:14:59,876 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:15:00,069 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:15:16,521 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:15:16,523 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:15:16,696 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:15:16,698 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:15:22,562 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:15:22,564 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:15:23,499 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:15:23,506 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:15:23,993 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:15:23,994 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:15:25,654 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:15:26,087 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:15:29,019 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:15:29,031 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:15:35,785 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:15:35,787 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:15:37,816 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:15:38,182 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:15:49,955 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:15:54,705 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:15:54,707 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:15:56,934 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:16:02,063 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:16:14,806 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:14,807 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:19,638 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:19,642 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:20,899 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:20,900 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:25,663 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:25,666 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:25,991 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:25,991 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:31,924 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:31,927 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:32,067 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:32,068 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:37,724 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:37,726 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:37,726 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1001/jamanetworkopen.2023.36408
# 2025-06-20 00:16:37,807 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:37,808 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:38,538 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:38,538 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:40,637 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:16:43,248 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:43,249 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:43,657 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:43,658 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:49,392 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:49,393 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:16:52,774 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:16:56,256 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:16:56,260 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:17:04,890 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:17:16,994 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:17:29,108 - WARNING - Rate limited on attempt 5 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:17:46,018 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:17:46,038 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:17:50,538 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:17:50,542 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:17:50,598 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:17:50,599 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:17:55,412 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:17:55,413 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:17:56,710 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:17:56,715 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:01,313 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:01,314 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:01,382 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:01,382 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:03,548 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:03,549 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:07,929 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:07,930 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:08,545 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:08,546 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:11,118 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:11,119 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:13,510 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:13,517 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:14,376 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:14,377 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:17,862 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:17,863 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:19,295 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:19,296 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:21,651 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:21,651 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:21,823 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:18:23,839 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:18:29,845 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:29,845 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:35,975 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:18:36,907 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:36,908 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:43,871 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:43,872 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:44,702 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:44,704 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:48,077 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:18:50,938 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:50,939 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:18:55,955 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:18:55,956 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:00,176 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:19:15,104 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:15,109 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:19,916 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:19,918 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:20,224 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:20,226 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:24,851 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:24,851 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:25,073 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:25,075 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:31,079 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:31,080 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:31,491 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:31,493 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:32,818 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:32,819 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:34,975 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:19:36,409 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:36,410 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:37,433 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:37,434 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:40,313 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:40,314 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:19:42,489 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:19:47,084 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:19:56,624 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:19:56,626 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:00,772 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:00,773 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:01,489 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:01,490 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:06,404 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:06,405 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:06,785 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:06,785 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:10,911 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:10,912 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:12,753 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:12,755 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:15,620 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:15,621 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:15,938 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:15,938 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:17,611 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:17,612 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:18,149 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:20:19,711 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:20:19,787 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:20:19,788 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:20:30,287 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:20:31,810 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:20:42,441 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:20:43,976 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:20:54,561 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:20:56,085 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:21:09,082 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:09,087 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:10,821 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:10,823 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:13,195 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:13,204 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:13,487 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:13,488 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:16,558 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:16,562 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:17,265 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:17,266 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:17,755 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:17,757 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:21,450 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:21,452 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:21,453 - WARNING - Invalid numeric code 6 for category poverty_context in DOI 10.1080/08263663.2023.2165316
# 2025-06-20 00:21:23,713 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:23,714 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:23,800 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:23,801 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:25,927 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:21:25,928 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:21:29,449 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:29,451 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:38,014 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:21:38,027 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:21:50,177 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:21:54,130 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:54,133 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:59,348 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:59,348 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:21:59,465 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:21:59,466 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:01,650 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:04,774 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:22:04,775 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:11,741 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:22:11,741 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:22:11,742 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:11,742 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:16,346 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:22:16,347 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:16,421 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:22:16,422 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:21,603 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:22:21,604 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:22,293 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:22:22,293 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:22,799 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:22:22,800 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:22:24,459 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:24,927 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:25,124 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:36,544 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:37,065 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:37,229 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:48,647 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:49,189 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:22:49,348 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:23:04,009 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:04,010 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:05,395 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:05,395 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:06,214 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:06,215 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:08,929 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:08,930 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:10,484 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:10,485 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:11,877 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:11,878 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:12,637 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:23:13,247 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:13,248 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:19,731 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:19,732 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:20,049 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:23:20,050 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:23:22,175 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:23:24,730 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:23:34,257 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:23:36,810 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:23:46,382 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:23:48,903 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:02,126 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:02,130 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:06,532 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:06,535 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:09,078 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:09,078 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:11,104 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:11,105 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:16,847 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:16,850 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:17,689 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:17,695 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:17,998 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:17,999 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:23,834 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:23,836 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:24,345 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:24,347 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:24,681 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:24:24,681 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:24:26,001 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:26,432 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:26,795 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:38,095 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:38,509 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:38,882 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:50,196 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:50,592 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:24:50,964 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:25:02,334 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:25:02,675 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:25:06,953 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:25:06,955 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:25:18,259 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:25:18,267 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:25:18,463 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:25:18,464 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:25:24,351 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:25:24,353 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:25:24,963 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:25:24,964 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:25:24,966 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:25:24,968 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:25:27,425 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:25:27,428 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:25:30,111 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:25:30,115 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:25:39,549 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:25:39,713 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:25:51,653 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:25:51,857 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:26:05,413 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:05,415 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:08,795 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:08,799 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:10,379 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:10,381 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:12,692 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:12,694 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:13,896 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:13,908 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:16,043 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:26:19,822 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:19,824 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:20,979 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:20,980 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:27,944 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:27,946 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:28,170 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:26:28,364 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:28,365 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:34,289 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:34,292 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:40,267 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:26:41,255 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:26:41,256 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:26:52,392 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:27:08,697 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:08,699 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:15,455 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:15,457 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:16,172 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:16,173 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:21,596 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:21,597 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:22,110 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:22,111 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:27,567 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:27,577 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:27,677 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:27,678 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:27,791 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:27,792 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:30,076 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:27:32,966 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:33,058 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:33,687 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:33,690 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:39,931 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:39,932 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:41,804 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:41,805 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:42,180 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:27:48,327 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:48,328 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:27:54,533 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:27:54,535 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:00,030 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:00,036 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:06,043 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:06,047 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:07,780 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:07,781 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:11,674 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:11,679 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:14,505 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:14,509 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:19,058 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:19,061 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:20,887 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:20,891 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:21,196 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:21,197 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:23,284 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:28:23,290 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:28:28,055 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:28,057 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:40,561 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:40,564 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:40,657 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:40,657 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:46,409 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:46,411 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:46,794 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:46,795 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:47,496 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:47,499 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:47,501 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1016/s2542-5196(23)00234-6
# 2025-06-20 00:28:49,599 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:28:51,812 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:51,814 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:52,424 - INFO - Successfully classified batch of 2 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:52,425 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:57,868 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:57,870 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:28:58,331 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:28:58,332 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:29:01,746 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 00:29:04,173 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:29:04,177 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:29:09,939 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 00:29:09,944 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 00:29:13,842 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# ...
# 2025-06-20 04:15:35,438 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:15:35,851 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:15:35,853 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:15:43,122 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:15:43,124 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:15:47,412 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:15:47,607 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:15:59,523 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:15:59,717 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:16:16,606 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:16,607 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:17,426 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:17,428 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:24,594 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:24,596 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:24,682 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:24,683 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:24,714 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:24,715 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:32,069 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:32,071 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:32,188 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:32,189 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:32,232 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:32,233 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:34,307 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:16:34,368 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:16:38,828 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:38,829 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:46,387 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:16:46,389 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:16:46,448 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:16:46,473 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:17:03,199 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:03,201 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:04,123 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:04,125 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:10,981 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:10,983 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:11,504 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:11,505 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:11,801 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:11,803 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:17,537 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:17,539 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:18,768 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:18,770 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:19,481 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:19,483 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:20,951 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:17:20,968 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:17:21,586 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:17:33,070 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:17:33,080 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:17:33,711 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:17:50,509 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:50,510 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:50,511 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:50,513 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:51,202 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:51,203 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:57,372 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:57,373 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:58,292 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:58,293 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:58,598 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:17:58,600 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:17:59,527 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:18:00,391 - WARNING - Rate limited on attempt 1 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:18:05,971 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:18:05,973 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:18:11,708 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:18:12,491 - WARNING - Rate limited on attempt 2 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:18:23,813 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:18:24,609 - WARNING - Rate limited on attempt 3 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:18:35,960 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:18:36,709 - WARNING - Rate limited on attempt 4 (initial) with API key AIzaSy... Waiting 10 seconds...
# 2025-06-20 04:18:53,282 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:18:53,284 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:18:53,588 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:18:53,589 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:04,856 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:19:04,858 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:05,567 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (initial attempt)
# 2025-06-20 04:19:05,568 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:05,579 - INFO - Attempting to retry 46 failed abstracts.
# 2025-06-20 04:19:05,586 - INFO - Retry attempt for 46 papers. 2 attempts remaining.
# 2025-06-20 04:19:05,660 - INFO - Created 10 retry batches using retry configurations.
# 2025-06-20 04:19:12,534 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:12,540 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:12,541 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1515/bis-2021-0047
# 2025-06-20 04:19:12,541 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.3389/fpubh.2023.1142577
# 2025-06-20 04:19:12,598 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:12,598 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:13,276 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:13,278 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:19,393 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:19,394 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:20,007 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:20,009 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:20,010 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1038/s41562-023-01684-9
# 2025-06-20 04:19:20,154 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:20,155 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:20,156 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.3368/le.100.1.102222-0092r
# 2025-06-20 04:19:26,767 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:26,769 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:26,929 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:26,929 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:26,929 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1257/aeri.20220550
# 2025-06-20 04:19:27,136 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:27,138 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:27,139 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1371/journal.pone.0286712
# 2025-06-20 04:19:27,140 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1371/journal.pone.0284821
# 2025-06-20 04:19:27,141 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1093/wber/lhad008
# 2025-06-20 04:19:32,608 - INFO - Successfully classified batch of 1 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:32,610 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:32,614 - INFO - Waiting for 5.00 seconds before next retry round.
# 2025-06-20 04:19:37,617 - INFO - Retry attempt for 8 papers. 1 attempts remaining.
# 2025-06-20 04:19:37,626 - INFO - Created 2 retry batches using retry configurations.
# 2025-06-20 04:19:43,973 - INFO - Successfully classified batch of 3 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:43,975 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:43,976 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1371/journal.pone.0284821
# 2025-06-20 04:19:43,977 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1093/wber/lhad008
# 2025-06-20 04:19:43,978 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1257/aeri.20220550
# 2025-06-20 04:19:44,584 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:19:44,586 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:19:44,587 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.3389/fpubh.2023.1142577
# 2025-06-20 04:19:44,588 - INFO - Waiting for 10.00 seconds before next retry round.
# 2025-06-20 04:19:54,599 - INFO - Retry attempt for 4 papers. 0 attempts remaining.
# 2025-06-20 04:19:54,605 - INFO - Created 1 retry batches using retry configurations.
# 2025-06-20 04:20:01,480 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSy... (retry attempt)
# 2025-06-20 04:20:01,481 - INFO - Successfully parsed JSON after extraction.
# 2025-06-20 04:20:01,482 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.3389/fpubh.2023.1142577
# 2025-06-20 04:20:01,483 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1371/journal.pone.0284821
# 2025-06-20 04:20:01,486 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1093/wber/lhad008
# 2025-06-20 04:20:01,487 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1257/aeri.20220550
# 2025-06-20 04:20:01,511 - WARNING - DOI 10.3389/fpubh.2023.1142577 not found in classification results, providing default 'Insufficient info' for all fields.
# 2025-06-20 04:20:01,551 - WARNING - DOI 10.1371/journal.pone.0284821 not found in classification results, providing default 'Insufficient info' for all fields.
# 2025-06-20 04:20:01,553 - WARNING - DOI 10.1093/wber/lhad008 not found in classification results, providing default 'Insufficient info' for all fields.
# 2025-06-20 04:20:01,555 - WARNING - DOI 10.1257/aeri.20220550 not found in classification results, providing default 'Insufficient info' for all fields.
# 2025-06-20 04:27:47,437 - INFO - Starting append operation - Spreadsheet: 1EMG3n3Ywt1X4Y-Z5eQCxyrZNA9Yzx00ALUe2HjsdeAQ, Sheet: Sheet1
# 2025-06-20 04:27:47,445 - INFO - Preparing data - DataFrame shape: (10131, 24), include_headers: False
# 2025-06-20 04:27:47,445 - INFO - Starting DataFrame validation and cleaning - Shape: (10131, 24)
# 2025-06-20 04:27:47,533 - INFO - Found 10131 NaN values across 1 columns
# 2025-06-20 04:27:47,534 - INFO - DataFrame validation completed
# 2025-06-20 04:27:47,534 - INFO - Applying comprehensive data sanitization...
# 2025-06-20 04:27:48,618 - INFO - Performing final JSON serialization validation...
# 2025-06-20 04:27:48,619 - INFO - JSON serialization validation passed
# 2025-06-20 04:27:48,619 - INFO - Data preparation completed - Total rows: 10131
# 2025-06-20 04:27:48,621 - INFO - Total rows to append: 10131
# 2025-06-20 04:27:48,621 - INFO - Processing batch 1 - Rows 0 to 1000
# 2025-06-20 04:28:36,878 - ERROR - Error appending data: <HttpError 400 when requesting https://sheets.googleapis.com/v4/spreadsheets/1EMG3n3Ywt1X4Y-Z5eQCxyrZNA9Yzx00ALUe2HjsdeAQ/values/Sheet1:append?valueInputOption=USER_ENTERED&insertDataOption=INSERT_ROWS&alt=json returned "This document is too large to continue editing.". Details: "[{'@type': 'type.googleapis.com/google.apps.sheets.v4.ErrorDetails', 'errorCode': 'DOCUMENT_TOO_LARGE_TO_EDIT'}]">

# %%
classified_results_df = pd.concat(classified_results, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 classified_results_df = pd.concat(classified_results, ignore_index=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/concat.py:448, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
# --> 448 ndims = self._get_ndims(objs)
#     449 sample, objs = self._get_sample_object(objs, ndims, keys, names, levels)
#     451 # Standardize axis parameter to int
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/concat.py:489, in _Concatenator._get_ndims(self, objs)
#     484     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     485         msg = (
#     486             f"cannot concatenate object of type '{type(obj)}'; "
#     487             "only Series and DataFrame objs are valid"
#     488         )
# --> 489         raise TypeError(msg)
#     491     ndims.add(obj.ndim)
#     492 return ndims
#
# TypeError: cannot concatenate object of type '<class 'dict'>'; only Series and DataFrame objs are valid
# 2025-06-13 08:42:59,639 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# 2025-06-13 08:42:59,640 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# 2025-06-13 08:42:59,684 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# 2025-06-13 08:42:59,689 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n}\n]'
# Arguments: ()
# 2025-06-13 08:43:05,734 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# 2025-06-13 08:43:05,766 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# 2025-06-13 08:43:05,768 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 54\n}\n]'
# Arguments: ()
# 2025-06-13 08:43:05,790 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]

# %%
classified_results_df = [pd.DataFrame([d]) for d in classified_results if isinstance(d, dict)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 classified_results_df = [pd.DataFrame([d]) for d in classified_results if isinstance(d, dict)]
#
# NameError: name 'classified_results' is not defined

# %%
classified_results_df = pd.concat(classified_results_df, ignore_index=True)
# Out:
# 2025-06-13 08:48:59,378 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# 2025-06-13 08:48:59,464 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# 2025-06-13 08:48:59,483 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n}\n]'
# Arguments: ()
# 2025-06-13 08:48:59,659 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]

# %%
google_sheets.append(
    classified_results_df, 
    spreadsheet_id=spreadsheet_id['papers'], 
    sheet_name='Sheet1'
)
# Out:
# 2025-06-13 08:50:26,545 - INFO - Starting append operation - Spreadsheet: 1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0, Sheet: Sheet1
# 2025-06-13 08:50:26,547 - INFO - Preparing data - DataFrame shape: (12573, 23), include_headers: False
# 2025-06-13 08:50:26,548 - INFO - Starting DataFrame validation and cleaning - Shape: (12573, 23)
# 2025-06-13 08:50:26,642 - INFO - Found 12580 NaN values across 3 columns
# 2025-06-13 08:50:26,643 - INFO - DataFrame validation completed
# 2025-06-13 08:50:26,643 - INFO - Applying comprehensive data sanitization...
# 2025-06-13 08:50:28,007 - INFO - Performing final JSON serialization validation...
# 2025-06-13 08:50:28,008 - INFO - JSON serialization validation passed
# 2025-06-13 08:50:28,008 - INFO - Data preparation completed - Total rows: 12573
# 2025-06-13 08:50:28,009 - INFO - Total rows to append: 12573
# 2025-06-13 08:50:28,009 - INFO - Processing batch 1 - Rows 0 to 1000
# 2025-06-13 08:50:30,795 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# 2025-06-13 08:50:30,841 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 29\n}\n]'
# Arguments: ()
# 2025-06-13 08:50:30,845 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# 2025-06-13 08:50:31,066 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# 2025-06-13 08:50:32,539 - ERROR - Error appending data: <HttpError 400 when requesting https://sheets.googleapis.com/v4/spreadsheets/1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0/values/Sheet1:append?valueInputOption=USER_ENTERED&insertDataOption=INSERT_ROWS&alt=json returned "This document is too large to continue editing.". Details: "[{'@type': 'type.googleapis.com/google.apps.sheets.v4.ErrorDetails', 'errorCode': 'DOCUMENT_TOO_LARGE_TO_EDIT'}]">
# 2025-06-13 08:50:36,874 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# 2025-06-13 08:50:36,926 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 23\n}\n]'
# Arguments: ()
# 2025-06-13 08:50:36,927 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# 2025-06-13 08:50:37,148 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# 2025-06-13 08:50:42,953 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# 2025-06-13 08:50:43,012 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 17\n}\n]'
# Arguments: ()
# 2025-06-13 08:50:43,021 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# 2025-06-13 08:50:43,234 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# 2025-06-13 08:50:49,056 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# 2025-06-13 08:50:49,109 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# 2025-06-13 08:50:49,113 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 10\n}\n]'
# Arguments: ()
# 2025-06-13 08:50:49,314 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# 2025-06-13 08:50:55,154 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# 2025-06-13 08:50:55,213 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# 2025-06-13 08:50:55,223 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 4\n}\n]'
# Arguments: ()
# 2025-06-13 08:50:55,388 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]

# %%
classified_results_df['fields'].value_counts()
# Out:
# 2025-06-13 08:50:06,447 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# 2025-06-13 08:50:06,447 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 53\n}\n]'
# Arguments: ()
# 2025-06-13 08:50:06,447 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# 2025-06-13 08:50:06,672 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fields'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 classified_results_df['fields'].value_counts()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'fields'
# 2025-06-13 08:50:12,530 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# 2025-06-13 08:50:12,531 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 47\n}\n]'
# Arguments: ()
# 2025-06-13 08:50:12,540 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# 2025-06-13 08:50:12,802 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# 2025-06-13 08:50:18,624 - ERROR - Error processing batch with API key AIzaSyAc...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# 2025-06-13 08:50:18,631 - ERROR - Error processing batch with API key AIzaSyB1...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# 2025-06-13 08:50:18,631 - ERROR - Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 443, in _process_batch_with_key
#     batch_raw_response = self._generate(
#                          ^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 169, in _generate
#     response = self.models[api_key].generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_10173/3038740364.py", line 461, in _process_batch_with_key
#     logger.error(f"Error processing batch with API key {api_key[:8]}...: {e}")
# Message: 'Error processing batch with API key AIzaSyD4...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {\n}\n, links {\n  description: "Learn more about Gemini API quotas"\n  url: "https://ai.google.dev/gemini-api/docs/rate-limits"\n}\n, retry_delay {\n  seconds: 41\n}\n]'
# Arguments: ()
# 2025-06-13 08:50:18,895 - ERROR - Error processing batch with API key AIzaSyD2...: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]

# %%
classifier = GeminiModel(
    api_keys=['AIzaSyBAP-xpwB-umiazKw895-zR9v8l_PULlgk' , 'AIzaSyBtSUqDqAkge2dOcCQ07CmmbWiB2IoOgL0', 'AIzaSyAfPuHj1ZwmPh7P4-Vzg2moLTGtRM1UfF8',
              'AIzaSyB6zWJJnRjcdbj_6KH09Hle4MnJ-9tF8fA', 'AIzaSyBsgOzMGft9bP2Gz-gdpBIoPEkgsFVid6s', 'AIzaSyDv8plW3CjrhQ8JTU15ay1B9rHNQvKU-EM',
              
              ])



# Example usage
results = classifier.classify(
                            dict_to_process,
                            study_types=study_types,
                            poverty_contexts=poverty_context,
                            mechanisms=mechanisms,
                            behaviors=behaviors
                        )
# Out:
# 2025-06-12 18:27:11,293 - INFO - Base prompt token overhead: 653 tokens
# 2025-06-12 18:27:11,293 - INFO - Initialized with 3 API keys for parallel processing
# 2025-06-12 18:27:11,303 - INFO - Processing 6270 abstracts in parallel using 3 API keys with numeric optimizations
# 2025-06-12 18:27:12,048 - INFO - Created 161 batches for parallel processing based on token limits
# 2025-06-12 18:27:27,253 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:27:27,256 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:27:27,556 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:27:27,557 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:27:27,768 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:27:27,770 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:27:43,839 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:27:43,841 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:27:45,684 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:27:45,686 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:27:48,447 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:27:48,449 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:00,736 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:28:00,740 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:03,602 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:28:03,604 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:04,216 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:28:04,218 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:18,246 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:28:18,248 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:19,270 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:28:19,271 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:20,806 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:28:20,807 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:33,817 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:28:33,818 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:35,449 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:28:35,451 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:35,518 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:28:35,520 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:48,865 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:28:48,868 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:50,400 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:28:50,402 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:28:50,420 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:28:50,421 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:04,533 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:29:04,535 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:05,145 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:29:05,148 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:05,453 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:29:05,454 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:19,790 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:29:19,791 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:20,813 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:29:20,815 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:21,531 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:29:21,532 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:36,481 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:29:36,483 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:36,673 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:29:36,675 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:42,773 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:29:42,775 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:54,300 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:29:54,301 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:57,782 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:29:57,784 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:29:58,395 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:29:58,396 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:09,538 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:30:09,540 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:13,653 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:30:13,654 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:30:13,655 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:13,656 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:13,657 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1375/1832427054936646
# 2025-06-12 18:30:28,603 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:30:28,605 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:28,788 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:30:28,790 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:30,881 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:30:30,883 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:44,270 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:30:44,272 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:46,216 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:30:46,218 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:30:46,728 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:30:46,730 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:01,208 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:31:01,209 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:01,369 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:31:01,371 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:02,089 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:31:02,090 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:17,346 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:31:17,347 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:17,400 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:31:17,400 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:17,401 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.1177/0886260505281439
# 2025-06-12 18:31:21,135 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:31:21,137 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:32,400 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:31:32,401 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:32,402 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1111/j.1467-6478.2005.00331.x
# 2025-06-12 18:31:36,496 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:31:36,497 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:36,554 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:31:36,559 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:36,563 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1097/00129191-200507000-00010
# 2025-06-12 18:31:36,581 - WARNING - Invalid numeric code 250 for category country_of_study in DOI 10.1177/0192512106058635
# 2025-06-12 18:31:51,549 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:31:51,550 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:51,551 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.1080/23323256.2005.11499916
# 2025-06-12 18:31:51,552 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.1504/ijem.2005.007356
# 2025-06-12 18:31:51,552 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.1586/14737167.5.2.205
# 2025-06-12 18:31:51,553 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.4102/ojvr.v72i4.175
# 2025-06-12 18:31:52,473 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:31:52,474 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:31:57,797 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:31:57,798 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:13,464 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:32:13,465 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:13,770 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:32:13,772 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:20,223 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:32:20,225 - WARNING - Direct JSON parse failed for API key AIzaSyC8...: Expecting ':' delimiter: line 545 column 5 (char 4694). Attempting robust extraction...
# 2025-06-12 18:32:20,225 - WARNING - JSON parse after stripping markdown failed for API key AIzaSyC8...: Expecting ':' delimiter: line 545 column 5 (char 4694). Attempting brace extraction...
# 2025-06-12 18:32:20,227 - ERROR - Error processing batch with API key AIzaSyC8...: Could not extract or parse valid JSON from response for API key AIzaSyC8... after all attempts: Extra data: line 17 column 4 (char 144). Problematic snippet: {
#     "0": [
#       999
#     ],
#     "1": [
#       999
#     ],
#     "2": [
#       999
#     ],
#     "3": [
#       999
#     ],
#     "4": [
#       999
#     ]
#   },
#   {
#     "0": [
#       999
#     ],
#     "1": [
#       0
#     ],
#     "2": [
#       999
#     ],
#     "3": [
#       999
#     ],
#     "4": [
#       125
#     ]
#   },
#   {
#     "0": [
#       12
#     ],
#     "1": [
#       0
#     ],
#     "2": [
#       999
#     ],
#     "3": [
#       12
#     ],
#     "4": [
#       999
#     ]
#   },
#   {
#     "0": [
#       999
#     ],
#     "1": [
#       999
#     ],
#     ...
# Problematic snippet: [
#   {
#     "0": [
#       999
#     ],
#     "1": [
#       999
#     ],
#     "2": [
#       999
#     ],
#     "3": [
#       999
#     ],
#     "4": [
#       999
#     ]
#   },
#   {
#     "0": [
#       999
#     ],
#     "1": [
#       0
#     ],
#     "2": [
#       999
#     ],
#     "3": [
#       999
#     ],
#     "4": [
#       125
#     ]
#   },
#   {
#     "0": [
#       12
#     ],
#     "1": [
#       0
#     ],
#     "2": [
#       999
#     ],
#     "3": [
#       12
#     ],
#     "4": [
#       999
#     ]
#   },
#   {
#     "0": [
#       999
#     ],
#     "1": [
#       999
#     ],
# 2025-06-12 18:32:29,336 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:32:29,342 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:29,950 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:32:29,951 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:41,727 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:32:41,730 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:44,081 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:32:44,083 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:45,002 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:32:45,003 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:56,574 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:32:56,576 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:59,957 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:32:59,959 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:32:59,963 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:32:59,964 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:11,730 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:33:11,731 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:16,030 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:33:16,032 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:21,458 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:33:21,460 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:31,301 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:33:31,304 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:33,440 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:33:33,441 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:42,771 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:33:42,775 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:48,598 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:33:48,601 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:49,618 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:33:49,619 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:33:58,221 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:33:58,224 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:03,749 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:34:03,751 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:04,324 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:34:04,326 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:12,965 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:34:12,967 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:12,968 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.1080/1462740500061160
# 2025-06-12 18:34:20,135 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:34:20,137 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:25,254 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:34:25,255 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:28,326 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:34:28,328 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:39,795 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:34:39,798 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:43,123 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:34:43,125 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:43,584 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:34:43,585 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:34:58,539 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:34:58,543 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:01,814 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:35:01,816 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:04,169 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:35:04,171 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:16,762 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:35:16,764 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:19,117 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:35:19,119 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:19,731 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:35:19,733 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:34,170 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:35:34,172 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:34,989 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:35:34,991 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:37,756 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:35:37,758 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:49,735 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:35:49,737 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:53,013 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:35:53,014 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:35:53,083 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:35:53,084 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:07,860 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:36:07,862 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:07,916 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:36:07,917 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:08,167 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:36:08,168 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:23,463 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:36:23,464 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:23,836 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:36:23,838 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:23,838 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.1017/s0022278x05280989
# 2025-06-12 18:36:23,839 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.1017/s0022278x05301376
# 2025-06-12 18:36:29,263 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:36:29,264 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:39,503 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:36:39,504 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:44,322 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:36:44,323 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:44,325 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1177/0022487105275920
# 2025-06-12 18:36:45,450 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:36:45,455 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:36:45,458 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1093/aler/ahi011
# 2025-06-12 18:36:59,778 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:36:59,779 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:00,905 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:37:00,905 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:37:00,906 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:00,907 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:14,014 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:37:14,017 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:15,753 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:37:15,755 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:16,572 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:37:16,574 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:29,167 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:37:29,169 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:31,317 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:37:31,319 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:32,454 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:37:32,457 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:44,559 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:37:44,561 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:47,190 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:37:47,192 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:37:47,468 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:37:47,470 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:00,195 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:38:00,197 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:02,144 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:38:02,146 - WARNING - Direct JSON parse failed for API key AIzaSyAl...: Expecting property name enclosed in double quotes: line 25 column 3 (char 1445). Attempting robust extraction...
# 2025-06-12 18:38:02,147 - WARNING - JSON parse after stripping markdown failed for API key AIzaSyAl...: Expecting property name enclosed in double quotes: line 25 column 3 (char 1445). Attempting brace extraction...
# 2025-06-12 18:38:02,148 - ERROR - Error processing batch with API key AIzaSyAl...: Could not extract or parse valid JSON from response for API key AIzaSyAl... after all attempts: Extra data: line 1 column 60 (char 59). Problematic snippet: {"0": [999], "1": [999], "2": [999], "3": [999], "4": [13]},
#   {"0": [999], "1": [999], "2": [999], "3": [999], "4": [999]},
#   {"0": [999], "1": [4], "2": [999], "3": [12], "4": [141]},
#   {"0": [999], "1": [2], "2": [999], "3": [999], "4": [228]},
#   {"0": [999], "1": [999], "2": [999], "3": [13], "4": [141]},
#   {"0": [6], "1": [0, 4], "2": [14], "3": [9, 11], "4": [228]},
#   {"0": [999], "1": [999], "2": [999], "3": [11], "4": [228]},
#   {"0": [999], "1": [999], "2": [999], "3": [999], "4": [155]}...
# 2025-06-12 18:38:02,311 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:38:02,313 - INFO - Successfully parsed JSON directly with explicit JSON output.
# Problematic snippet: [
#   {"0": [999], "1": [999], "2": [999], "3": [999], "4": [13]},
#   {"0": [999], "1": [999], "2": [999], "3": [999], "4": [999]},
#   {"0": [999], "1": [4], "2": [999], "3": [12], "4": [141]},
#   {"0": [999], "1": [2], "2": [999], "3": [999], "4": [228]},
#   {"0": [999], "1": [999], "2": [999], "3": [13], "4": [141]},
#   {"0": [6], "1": [0, 4], "2": [14], "3": [9, 11], "4": [228]},
#   {"0": [999], "1": [999], "2": [999], "3": [11], "4": [228]},
#   {"0": [999], "1": [999], "2": [999], "3": [999], "4": [1
# 2025-06-12 18:38:16,580 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:38:16,583 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:18,320 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:38:18,322 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:24,260 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:38:24,262 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:31,840 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:38:31,842 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:39,210 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:38:39,211 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:40,203 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:38:40,204 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:46,992 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:38:46,994 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:38:55,597 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:38:55,599 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:01,535 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:39:01,536 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:39:01,537 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:01,538 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:10,752 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:39:10,754 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:17,202 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:39:17,203 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:19,458 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:39:19,461 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:25,290 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:39:25,291 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:32,564 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:39:32,569 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:33,998 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:39:33,999 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:40,548 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:39:40,549 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:49,356 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:39:49,358 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:53,964 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:39:53,965 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:39:53,966 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1093/jae/eji020
# 2025-06-12 18:39:56,215 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:39:56,217 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:09,623 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:40:09,625 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:09,626 - WARNING - Invalid numeric code 33 for category study_type in DOI 10.1080/14649370500316737
# 2025-06-12 18:40:09,835 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:40:09,836 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:10,851 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:40:10,853 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:24,470 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:40:24,472 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:25,185 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:40:25,186 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:26,926 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:40:26,927 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:39,932 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:40:39,934 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:41,466 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:40:41,467 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:41,675 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:40:41,677 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:54,470 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:40:54,472 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:40:54,473 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1505/ifor.2005.7.2.82
# 2025-06-12 18:40:56,426 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:40:56,428 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:02,560 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:41:02,562 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:09,525 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:41:09,527 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:17,511 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:41:17,514 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:17,726 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:41:17,728 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:24,370 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:41:24,371 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:32,255 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:41:32,255 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:33,076 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:41:33,076 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:39,733 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:41:39,737 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:48,234 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:41:48,235 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:49,151 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:41:49,153 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:41:54,887 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:41:54,888 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:04,000 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:42:04,001 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:04,717 - INFO - Successfully classified batch of 39 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:42:04,718 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:04,719 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1111/j.1728-4465.2005.00039.x
# 2025-06-12 18:42:04,719 - WARNING - Invalid numeric code 1 for category study_type in DOI 10.1300/j369v08n02_06
# 2025-06-12 18:42:08,813 - INFO - Successfully classified batch of 30 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:42:08,815 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:08,816 - INFO - Initiating retry for 184 failed papers
# 2025-06-12 18:42:08,817 - INFO - Retry attempt 1/3 for 184 papers
# 2025-06-12 18:42:08,882 - INFO - Created 37 retry batches
# 2025-06-12 18:42:16,762 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:42:16,765 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:16,894 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:42:16,896 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:17,312 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:42:17,314 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:25,197 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:42:25,199 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:25,557 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:42:25,559 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:25,722 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:42:25,724 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:34,004 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:42:34,005 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:42:34,005 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:42:34,006 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:34,007 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:34,008 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:42,606 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:42:42,607 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:42,694 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:42:42,695 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:42,744 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:42:42,745 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:42,745 - ERROR - Error processing batch with API key AIzaSyAu...: unhashable type: 'list'
# 2025-06-12 18:42:51,001 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:42:51,002 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:51,310 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:42:51,310 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:42:51,311 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:51,312 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:59,741 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:42:59,742 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:42:59,762 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:42:59,763 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:00,013 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:43:00,014 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:08,104 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:43:08,105 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:08,411 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:43:08,412 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:08,427 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:43:08,428 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:15,989 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:43:15,991 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:16,603 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:43:16,604 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:17,320 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:43:17,321 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:24,286 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:43:24,287 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:25,717 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:43:25,718 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:25,876 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:43:25,877 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:32,885 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:43:32,886 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:34,317 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:43:34,318 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:43:34,318 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:34,318 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:41,282 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:43:41,283 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:42,715 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:43:42,716 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:42,812 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:43:42,813 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:49,781 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:43:49,782 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:51,111 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyC8...
# 2025-06-12 18:43:51,111 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAu...
# 2025-06-12 18:43:51,111 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:51,112 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:57,769 - INFO - Successfully classified batch of 4 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:43:57,770 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:43:59,777 - INFO - Retry attempt 2/3 for 5 papers
# 2025-06-12 18:43:59,787 - INFO - Created 1 retry batches
# 2025-06-12 18:44:08,521 - INFO - Successfully classified batch of 5 abstracts using API key: AIzaSyAl...
# 2025-06-12 18:44:08,522 - INFO - Successfully parsed JSON directly with explicit JSON output.
# 2025-06-12 18:44:12,550 - INFO - Classification complete. Processed 6270 abstracts.

# %%
6270/39
# Out:
# 160.76923076923077

# %%
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#                                 doi  \
# 0     10.1177/10253823050120020104x
# 1            10.1001/jama.294.5.571
# 2             10.1353/hpu.2005.0038
# 3          10.1136/jech.2005.039180
# 4  10.1111/j.0038-4941.2005.00321.x
#
#                                                title  link  \
# 0  Poverty, gender and mental health promotion in...   NaN
# 1  Mental Health of Cambodian Refugees 2 Decades ...   NaN
# 2  Barriers to Health and Social Services for Str...   NaN
# 3  Maternal mental health and child nutritional s...   NaN
# 4  Race/Ethnic Differences in Nonspecific Psychol...   NaN
#
#                                              authors  \
# 0                                   ['Vikram Patel']
# 1                              ['Grant N. Marshall']
# 2  ['Steven P. Kurtz', 'Hilary L. Surratt', 'Mari...
# 3                                  ['Trudy Harpham']
# 4            ['Jenifer L. Bratter', 'Karl Eschbach']
#
#                      keyword publication                   country  date  \
# 0  Poverty and mental health    OpenAlex                    [None]  2005
# 1  Poverty and mental health    OpenAlex                    ['US']  2005
# 2  Poverty and mental health    OpenAlex  ['US', None, None, None]  2005
# 3  Poverty and mental health    OpenAlex                    ['GB']  2005
# 4  Poverty and mental health    OpenAlex              ['US', 'US']  2005
#
#        field                                        institution  ...  \
# 0  Affective                                             [None]  ...
# 1  Affective                               ['RAND Corporation']  ...
# 2  Affective       ['University of Delaware', None, None, None]  ...
# 3  Affective                   ['London South Bank University']  ...
# 4  Affective  ['University of Houston', 'The University of T...  ...
#
#                                            embedding      UMAP1     UMAP2  \
# 0  [0.0949455052614212, -0.022747956216335297, -0...  12.368342  5.261272
# 1  [0.06730816513299942, 0.009284263476729393, -0...  14.557115  4.056287
# 2  [-0.007396651431918144, -0.06940397620201111, ...  14.353561  3.524021
# 3  [0.05841507390141487, 0.030578309670090675, -0...  15.548842  4.862946
# 4  [0.07612796872854233, 0.028869790956377983, -0...  14.888777  4.692533
#
#   predicted_label confidence                study_type  \
# 0         Related        1.0         Insufficient info
# 1         Related        1.0           Cross-sectional
# 2         Related        1.0  Interviews, Focus groups
# 3         Related        1.0           Cross-sectional
# 4         Related        1.0           Cross-sectional
#
#                           poverty_context                      mechanism  \
# 0  Low resource level, Social environment              Insufficient info
# 1  Low resource level, Social environment                Anxiety, Stress
# 2  Low resource level, Social environment              Insufficient info
# 3                      Low resource level  Depression, Insufficient info
# 4  Low resource level, Social environment              Insufficient info
#
#             behavior                                 country_of_study
# 0  Insufficient info                                Insufficient info
# 1  Insufficient info                                           Tuvalu
# 2  Insufficient info                                           Tuvalu
# 3          Food diet  Côte d'Ivoire, Guadeloupe, Uzbekistan, Pitcairn
# 4  Insufficient info                                           Tuvalu
#
# [5 rows x 24 columns]

# %%
results_df.drop(columns=['country_of_study'], inplace=True)

# %%
country_extractor_func = create_country_extractor_function(method='spacy')
results_df['country_of_study'] = results_df['abstract'].apply(country_extractor_func)

# %%
list(results_df[results_df['doi']== '10.1505/ifor.2005.7.4.294']['abstract'])
# Out:
# ['Weighted goal programming (WGP) is employed to reconcile the goals of food security, improved incomes and woodland conservation in households from selected sites in Malawi, Mozambique and Zimbabwe.The three goals are attainable simultaneously, albeit with trade-offs useful in guiding development of rural development policies.The WGP model provides a framework for evaluating impact, on the household goals and woodland condition, of some macroeconomic and sectoral policies and demographic changes.']

# %%
len(results)
# Out:
# 6270

# %%
# Out:
# 2025-06-12 20:11:43,067 - INFO - Initializing Google Sheets API
# 2025-06-12 20:11:43,068 - INFO - Building Google Sheets service
# 2025-06-12 20:11:43,115 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2025-06-12 20:11:43,123 - INFO - Google Sheets service built successfully
# 2025-06-12 20:11:43,124 - INFO - API initialized with batch size: 1000
# 2025-06-12 20:11:43,124 - INFO - Starting replace operation - Spreadsheet: 1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0, Sheet: Sheet1
# 2025-06-12 20:11:43,125 - INFO - Checking if sheet exists
# 2025-06-12 20:11:44,303 - INFO - Sheet 'Sheet1' exists
# 2025-06-12 20:11:44,305 - INFO - Clearing existing content from sheet
# 2025-06-12 20:11:44,913 - INFO - Sheet cleared
# 2025-06-12 20:11:44,916 - INFO - Preparing data - DataFrame shape: (6270, 24), include_headers: True
# 2025-06-12 20:11:44,916 - INFO - Starting DataFrame validation and cleaning - Shape: (6270, 24)
# 2025-06-12 20:11:44,995 - INFO - Found 6287 NaN values across 2 columns
# 2025-06-12 20:11:44,995 - INFO - DataFrame validation completed
# 2025-06-12 20:11:44,995 - INFO - Applying comprehensive data sanitization...
# 2025-06-12 20:11:45,907 - INFO - Performing final JSON serialization validation...
# 2025-06-12 20:11:45,908 - INFO - JSON serialization validation passed
# 2025-06-12 20:11:45,909 - INFO - Data preparation completed - Total rows: 6271
# 2025-06-12 20:11:45,910 - INFO - Total rows to replace: 6271
# 2025-06-12 20:11:45,910 - INFO - Processing batch 1 - Rows 0 to 1000
# 2025-06-12 20:11:45,910 - INFO - Starting batch update - Sheet: Sheet1, Start row: 1, Rows to update: 1000
# 2025-06-12 20:11:50,344 - INFO - Batch update completed - Cells updated: 24000
# 2025-06-12 20:11:50,346 - INFO - Batch 1: Cells updated: 24000
# 2025-06-12 20:11:50,851 - INFO - Processing batch 2 - Rows 1000 to 2000
# 2025-06-12 20:11:50,853 - INFO - Starting batch update - Sheet: Sheet1, Start row: 1001, Rows to update: 1000
# 2025-06-12 20:11:54,746 - INFO - Batch update completed - Cells updated: 24000
# 2025-06-12 20:11:54,748 - INFO - Batch 2: Cells updated: 24000
# 2025-06-12 20:11:55,255 - INFO - Processing batch 3 - Rows 2000 to 3000
# 2025-06-12 20:11:55,256 - INFO - Starting batch update - Sheet: Sheet1, Start row: 2001, Rows to update: 1000
# 2025-06-12 20:11:58,945 - INFO - Batch update completed - Cells updated: 24000
# 2025-06-12 20:11:58,946 - INFO - Batch 3: Cells updated: 24000
# 2025-06-12 20:11:59,447 - INFO - Processing batch 4 - Rows 3000 to 4000
# 2025-06-12 20:11:59,449 - INFO - Starting batch update - Sheet: Sheet1, Start row: 3001, Rows to update: 1000
# 2025-06-12 20:12:02,940 - INFO - Batch update completed - Cells updated: 24000
# 2025-06-12 20:12:02,945 - INFO - Batch 4: Cells updated: 24000
# 2025-06-12 20:12:03,452 - INFO - Processing batch 5 - Rows 4000 to 5000
# 2025-06-12 20:12:03,453 - INFO - Starting batch update - Sheet: Sheet1, Start row: 4001, Rows to update: 1000
# 2025-06-12 20:12:07,032 - INFO - Batch update completed - Cells updated: 24000
# 2025-06-12 20:12:07,033 - INFO - Batch 5: Cells updated: 24000
# 2025-06-12 20:12:07,538 - INFO - Processing batch 6 - Rows 5000 to 6000
# 2025-06-12 20:12:07,540 - INFO - Starting batch update - Sheet: Sheet1, Start row: 5001, Rows to update: 1000
# 2025-06-12 20:12:10,822 - INFO - Batch update completed - Cells updated: 24000
# 2025-06-12 20:12:10,824 - INFO - Batch 6: Cells updated: 24000
# 2025-06-12 20:12:11,330 - INFO - Processing batch 7 - Rows 6000 to 6271
# 2025-06-12 20:12:11,332 - INFO - Starting batch update - Sheet: Sheet1, Start row: 6001, Rows to update: 271
# 2025-06-12 20:12:12,255 - INFO - Batch update completed - Cells updated: 6504
# 2025-06-12 20:12:12,256 - INFO - Batch 7: Cells updated: 6504
# 2025-06-12 20:12:12,256 - INFO - Replace operation completed - Total rows replaced: 6271
# [{'spreadsheetId': '1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0',
#   'updatedRange': 'Sheet1!A1:X1000',
#   'updatedRows': 1000,
#   'updatedColumns': 24,
#   'updatedCells': 24000},
#  {'spreadsheetId': '1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0',
#   'updatedRange': 'Sheet1!A1001:X2000',
#   'updatedRows': 1000,
#   'updatedColumns': 24,
#   'updatedCells': 24000},
#  {'spreadsheetId': '1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0',
#   'updatedRange': 'Sheet1!A2001:X3000',
#   'updatedRows': 1000,
#   'updatedColumns': 24,
#   'updatedCells': 24000},
#  {'spreadsheetId': '1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0',
#   'updatedRange': 'Sheet1!A3001:X4000',
#   'updatedRows': 1000,
#   'updatedColumns': 24,
#   'updatedCells': 24000},
#  {'spreadsheetId': '1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0',
#   'updatedRange': 'Sheet1!A4001:X5000',
#   'updatedRows': 1000,
#   'updatedColumns': 24,
#   'updatedCells': 24000},
#  {'spreadsheetId': '1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0',
#   'updatedRange': 'Sheet1!A5001:X6000',
#   'updatedRows': 1000,
#   'updatedColumns': 24,
#   'updatedCells': 24000},
#  {'spreadsheetId': '1nrZC6zJ50DouMCHIWZOl-tQ4BAZfEojJymtzUh26nP0',
#   'updatedRange': 'Sheet1!A6001:X6271',
#   'updatedRows': 271,
#   'updatedColumns': 24,
#   'updatedCells': 6504}]

# %%
from featureEngineering import topicClusters

all_papers = pd.concat(excels, ignore_index=True)


all_papers['UMAP1'] = all_papers['UMAP1'].astype(float)
all_papers['UMAP2'] = all_papers['UMAP2'].astype(float)

papers_list = all_papers.to_dict(orient='records')

clusters = topicClusters.run(
    papers = papers_list,
    n_clusters= 12
)

# %%
results_df = pd.DataFrame(clusters[1])
results_df.head()
# Out:
#                                 doi  \
# 0     10.1177/10253823050120020104x
# 1            10.1001/jama.294.5.571
# 2             10.1353/hpu.2005.0038
# 3          10.1136/jech.2005.039180
# 4  10.1111/j.0038-4941.2005.00321.x
#
#                                                title  link  \
# 0  Poverty, gender and mental health promotion in...   NaN
# 1  Mental Health of Cambodian Refugees 2 Decades ...   NaN
# 2  Barriers to Health and Social Services for Str...   NaN
# 3  Maternal mental health and child nutritional s...   NaN
# 4  Race/Ethnic Differences in Nonspecific Psychol...   NaN
#
#                                              authors  \
# 0                                   ['Vikram Patel']
# 1                              ['Grant N. Marshall']
# 2  ['Steven P. Kurtz', 'Hilary L. Surratt', 'Mari...
# 3                                  ['Trudy Harpham']
# 4            ['Jenifer L. Bratter', 'Karl Eschbach']
#
#                      keyword publication                   country  date  \
# 0  Poverty and mental health    OpenAlex                    [None]  2005
# 1  Poverty and mental health    OpenAlex                    ['US']  2005
# 2  Poverty and mental health    OpenAlex  ['US', None, None, None]  2005
# 3  Poverty and mental health    OpenAlex                    ['GB']  2005
# 4  Poverty and mental health    OpenAlex              ['US', 'US']  2005
#
#        field                                        institution  \
# 0  Affective                                             [None]
# 1  Affective                               ['RAND Corporation']
# 2  Affective       ['University of Delaware', None, None, None]
# 3  Affective                   ['London South Bank University']
# 4  Affective  ['University of Houston', 'The University of T...
#
#                                             abstract  cited_by_count  \
# 0  which is computed on the basis of a number of ...              29
# 1  Little is known about the long-term mental hea...             647
# 2  Homelessness, poverty, drug abuse and violent ...             202
# 3  <b>Objective:</b> To test the hypothesis that ...             257
# 4  Objective. This article documents the patterns...             177
#
#   citing_works                                   referenced_works  \
# 0           []  ['W137796145', 'W1563422447', 'W1595706829', '...
# 1           []  ['W1489641999', 'W1498057507', 'W1663918944', ...
# 2           []  ['W117577764', 'W1488716830', 'W1510369582', '...
# 3           []  ['W1481892733', 'W1508821355', 'W1603277768', ...
# 4           []  ['W150846618', 'W1531151302', 'W1928999099', '...
#
#                                            embedding      UMAP1     UMAP2  \
# 0  [0.0949455052614212, -0.022747956216335297, -0...  12.368342  5.261272
# 1  [0.06730816513299942, 0.009284263476729393, -0...  14.557115  4.056287
# 2  [-0.007396651431918144, -0.06940397620201111, ...  14.353561  3.524021
# 3  [0.05841507390141487, 0.030578309670090675, -0...  15.548842  4.862946
# 4  [0.07612796872854233, 0.028869790956377983, -0...  14.888777  4.692533
#
#   predicted_label  confidence  cluster
# 0         Related         1.0        7
# 1         Related         1.0        6
# 2         Related         1.0        6
# 3         Related         1.0        6
# 4         Related         1.0        6

# %%
from data import googleSheets
import importlib

importlib.reload(googleSheets)

google_sheets = googleSheets.API(credentials_json=credenetials)

# Upload the results DataFrame to Google Sheets
google_sheets.replace(
    results_df, 
    spreadsheet_id=spreadsheet_id['papers'], 
    sheet_name='Sheet1'
    )

# %%
results_df = generate(topics_df, 
                      n_terms=5, 
                      min_df=10, 
                      max_df=0.99, 
                      term_column='title', 
                      cluster_column='cluster')

# %%
results_df
# Out:
#     cluster                                              title  \
# 0         0  Mental health promotion in public health, What...
# 1         1  SUMMARIES/ZUSAMMENFASSUNGEN RESUMIDAS/PRÉCIS, ...
# 2         2  Human Rights and Capabilities, Human security ...
# 3         3  Estimating water demand for domestic use in ru...
# 4         4  Social Vulnerabilities and Hurricane Katrina: ...
# 5         5  Behavioral Economics and Marketing in Aid of D...
# 6         6  Mental Health of Cambodian Refugees 2 Decades ...
# 7         7  Poverty, gender and mental health promotion in...
# 8         8  The Staircase to Terrorism: A Psychological Ex...
# 9         9  Abstracts, Key Lectures, Abstracts, Agricultur...
# 10       10  The Status of Low-Income Neighborhoods in the ...
# 11       11  Revisiting the Parable of the Prodigal Son for...
#
#                                              abstract  umap_1_mean  \
# 0   La sante mentale est un etat de bien-etre dans...     8.962639
# 1   Restricted accessAbstractFirst published June ...    -3.972352
# 2   The two concepts — human rights and capabiliti...     9.923976
# 3   The paper applies the travel cost method (TCM)...     0.856667
# 4   Social science research on natural disasters d...     6.291086
# 5   This article considers several aspects of the ...     5.135398
# 6   Little is known about the long-term mental hea...    14.672923
# 7   which is computed on the basis of a number of ...    13.202727
# 8   To foster a more in-depth understanding of the...     8.620198
# 9   Restricted accessAbstractFirst published April...     3.493768
# 10  It has long been recognized that children and ...    11.482156
# 11  Abstract The early Christian Gospels' most rad...    11.303960
#
#     umap_2_mean                          label
# 0     -0.210486            church food systems
# 1      8.249377        tobacco tobacco control
# 2      5.809490                press statement
# 3     -1.193828            scp scp immigration
# 4      6.697604              medicaid care act
# 5      3.230848           statement discussion
# 6      2.968043  antiretroviral american women
# 7      5.875512          care act child health
# 8      3.316085            civil society press
# 9     16.751293                     earth prep
# 10     2.486310                 foreign aid pp
# 11    10.036650                 engineering da

# %%
import pandas as pd 

gemini_api = GeminiModel('AIzaSyDAR99qLXKX_phG9gyUfR5SBb93vNqadZ4', batch_size = 50, delay = 2, model_name = 'gemini-2.0-flash-lite' ) 

study_types = [item for subcat in file['study_types'].values() for method_list in subcat.values() for item in method_list]
poverty_context = list(file['poverty_contexts'].values())
mechanisms = [item for subcat in file['mechanisms'].values() for item in subcat]
behaviors = [item for subcat in file['Behaviors'].values() for item in subcat]

results =  []


df = pd.read_csv(f'data/extractedPapers20{12}.csv')
results = gemini_api.classify(papers = df.to_dict(orient='records'), 
                            study_types =study_types, 
                            poverty_contexts = poverty_context, 
                            mechanisms = mechanisms, 
                            behaviors = behaviors)

# results.extend(classified)  

# results
# Out:
# 2025-06-11 16:59:25,678 - INFO - Initialized with 1 API keys for parallel processing
# 2025-06-11 16:59:26,984 - INFO - Processing 11588 abstracts in parallel using 1 API keys
# 2025-06-11 16:59:26,987 - INFO - Created 232 batches for parallel processing
# 2025-06-11 16:59:27,868 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyDA...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyDA...'
# Arguments: ()
# 2025-06-11 16:59:28,305 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyBu...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyBu...'
# Arguments: ()
# 2025-06-11 16:59:29,986 - ERROR - Error generating classification with API key AIzaSyBu...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyBu...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:30,172 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyCI...
# 2025-06-11 16:59:32,304 - ERROR - Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:32,321 - ERROR - Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# 2025-06-11 16:59:34,459 - ERROR - Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:34,468 - ERROR - Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# 2025-06-11 16:59:36,457 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyCF...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyCF...'
# Arguments: ()
# 2025-06-11 16:59:36,462 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.7448/ias.15.4.17404
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 251, in _process_batch_with_key
#     decoded_results, invalid_papers = self._decode_numeric_labels(numeric_results)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 209, in _decode_numeric_labels
#     logger.warning(f"Invalid numeric code {code} for category {category} in DOI {doi}")
# Message: 'Invalid numeric code 249 for category country_of_study in DOI 10.7448/ias.15.4.17404'
# Arguments: ()
# 2025-06-11 16:59:36,580 - ERROR - Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:36,601 - ERROR - Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# 2025-06-11 16:59:38,783 - ERROR - Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# 2025-06-11 16:59:38,793 - ERROR - Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:40,919 - ERROR - Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:40,945 - ERROR - Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# 2025-06-11 16:59:41,418 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyCF...
# 2025-06-11 16:59:43,067 - ERROR - Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# 2025-06-11 16:59:43,071 - ERROR - Error generating classification with API key AIzaSyCI...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
# ...
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyDA...'
# Arguments: ()
# 2025-06-11 17:08:10,047 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyBu...
# 2025-06-11 17:08:24,464 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyDA...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyDA...'
# Arguments: ()
# 2025-06-11 17:08:31,771 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyDA...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyDA...'
# Arguments: ()
# 2025-06-11 17:08:33,325 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyCF...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyCF...'
# Arguments: ()
# 2025-06-11 17:08:33,876 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyBu...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyBu...'
# Arguments: ()
# 2025-06-11 17:08:33,878 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.1186/1471-244x-12-165
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 251, in _process_batch_with_key
#     decoded_results, invalid_papers = self._decode_numeric_labels(numeric_results)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 209, in _decode_numeric_labels
#     logger.warning(f"Invalid numeric code {code} for category {category} in DOI {doi}")
# Message: 'Invalid numeric code 249 for category country_of_study in DOI 10.1186/1471-244x-12-165'
# Arguments: ()
# 2025-06-11 17:08:34,147 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyBu...
# 2025-06-11 17:08:36,429 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyDA...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyDA...'
# Arguments: ()
# 2025-06-11 17:08:37,689 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyBu...

# %%
results
# Out:
# 2025-06-11 16:59:06,316 - ERROR - Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyB9...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:07,649 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyCF...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyCF...'
# Arguments: ()
# []
# 2025-06-11 16:59:14,333 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyCF...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 176, in classify_batch
#     logger.info(f"Successfully classified batch of {len(abstracts_batch)} abstracts using API key: {api_key[:8]}...")
# Message: 'Successfully classified batch of 50 abstracts using API key: AIzaSyCF...'
# Arguments: ()
# 2025-06-11 16:59:16,479 - ERROR - Error generating classification with API key AIzaSyD1...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyD1...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:18,638 - ERROR - Error generating classification with API key AIzaSyCR...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 175, in classify_batch
#     response = self._generate(prompt, api_key)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 92, in _generate
#     output = self.models[api_key].generate_content(prompt).text
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/opt/anaconda3/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 573, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.11/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 236, in _process_batch_with_key
#     batch_results = self.classify_batch(batch, study_types, poverty_contexts, mechanisms, behaviors, api_key)
#   File "/var/folders/gr/mhlc8kfs39b7v4v54d1fd4bc0000gn/T/ipykernel_1744/1966920006.py", line 180, in classify_batch
#     logger.error(f"Error generating classification with API key {api_key[:8]}...: {e}")
# Message: 'Error generating classification with API key AIzaSyCR...: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"\ndomain: "googleapis.com"\nmetadata {\n  key: "service"\n  value: "generativelanguage.googleapis.com"\n}\n, locale: "en-US"\nmessage: "API key expired. Please renew the API key."\n]'
# Arguments: ()
# 2025-06-11 16:59:19,936 - INFO - Successfully classified batch of 50 abstracts using API key: AIzaSyDA...
# 2025-06-11 16:59:19,941 - WARNING - Invalid numeric code 249 for category country_of_study in DOI 10.7448/ias.15.3.17366

# %%
import pandas as pd

results_df = pd.DataFrame(results)
results_df['poverty_context'].value_counts()
# Out:
# poverty_context
# Insufficient info                                                                                          15757
# Low resource level                                                                                          9396
# Social environment                                                                                          5477
# Low resource level, Social environment                                                                      4292
# Low resource level, Human capital inputs                                                                    1253
# Low resource level, Physical environment                                                                    1032
# Human capital inputs                                                                                         795
# Physical environment                                                                                         450
# Low resource level, Resource volatility                                                                      417
# Physical environment, Social environment                                                                     314
# Low resource level, Physical environment, Social environment                                                 304
# Human capital inputs, Social environment                                                                     244
# Low resource level, Human capital inputs, Social environment                                                 230
# Resource volatility                                                                                          145
# Social environment, Low resource level                                                                       119
# Low resource level, Resource volatility, Physical environment                                                 82
# Physical environment, Low resource level                                                                      75
# Resource volatility, Physical environment                                                                     59
# Low resource level, Physical environment, Human capital inputs                                                38
# Resource volatility, Social environment                                                                       33
# Low resource level, Resource volatility, Social environment                                                   29
# Social environment, Human capital inputs                                                                      29
# Physical environment, Human capital inputs                                                                    23
# Low resource level, Resource volatility, Physical environment, Social environment                             23
# Low resource level, Physical environment, Human capital inputs, Social environment                            12
# Social environment, Physical environment                                                                       9
# Physical environment, Resource volatility                                                                      8
# Human capital inputs, Low resource level                                                                       7
# Resource volatility, Low resource level                                                                        6
# Resource volatility, Physical environment, Social environment                                                  6
# Low resource level, Resource volatility, Human capital inputs                                                  5
# Low resource level, Physical environment, Resource volatility                                                  4
# Physical environment, Human capital inputs, Social environment                                                 4
# Physical environment, Social environment, Low resource level                                                   4
# Low resource level, Resource volatility, Physical environment, Human capital inputs, Social environment        4
# Low resource level, Social environment, Physical environment                                                   3
# Low resource level, Resource volatility, Physical environment, Human capital inputs                            3
# Low resource level, Insufficient info                                                                          3
# Low resource level, Social environment, Human capital inputs                                                   3
# Human capital inputs, Social environment, Low resource level                                                   3
# Physical environment, Insufficient info                                                                        2
# Resource volatility, Physical environment, Low resource level                                                  2
# Social environment, Resource volatility                                                                        2
# Social environment, Insufficient info                                                                          2
# Resource volatility, Human capital inputs, Social environment                                                  2
# Social environment, Human capital inputs, Low resource level                                                   1
# Insufficient info, Social environment                                                                          1
# Social environment, Low resource level, Resource volatility                                                    1
# Resource volatility, Social environment, Low resource level                                                    1
# Human capital inputs, Insufficient info                                                                        1
# Name: count, dtype: int64

# %%
results_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results_df.head()
#
# NameError: name 'results_df' is not defined

# %%
results_df['country_of_study'].value_counts()
# Out:
# country_of_study
# Insufficient info                                                                                                                                         9880
# Turks and Caicos Islands                                                                                                                                  2157
# United States Minor Outlying Islands                                                                                                                       992
# Tuvalu                                                                                                                                                     961
# Tunisia                                                                                                                                                    937
#                                                                                                                                                           ...
# Syrian Arab Republic, Faroe Islands, Trinidad and Tobago                                                                                                     1
# Comoros, Cook Islands, Iran, Islamic Republic of, Kazakhstan, Korea, Democratic People's Republic of, Panama, Sri Lanka, Tokelau, United Arab Emirates       1
# Comoros, Paraguay                                                                                                                                            1
# Bolivia, Plurinational State of, Macao, South Sudan                                                                                                          1
# Fiji, Poland                                                                                                                                                 1
# Name: count, Length: 1878, dtype: int64

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Fetch API key from environment variables
api_key = os.getenv("GEMINI_API_KEY")

# Load Google Sheets credentials from environment variables
type= os.getenv("type")
project_id = os.getenv("project_id")
private_key_id = os.getenv("private_key_id") 
private_key = os.getenv("private_key").replace("\\n", "\n")  
client_email = os.getenv("client_email")
client_id = os.getenv("client_id")
auth_uri = os.getenv("auth_uri")
token_uri = os.getenv("token_uri")
auth_provider_x509_cert_url = os.getenv("auth_provider_x509_cert_url")
client_x509_cert_url= os.getenv("client_x509_cert_url")
universe_domain= os.getenv("universe_domain")
credenetials = {
    "type": type,
    "project_id": project_id,
    "private_key_id": private_key_id,
    "private_key": private_key,
    "client_email": client_email,
    "client_id": client_id,
    "auth_uri": auth_uri,
    "token_uri": token_uri,
    "auth_provider_x509_cert_url": auth_provider_x509_cert_url,
    "client_x509_cert_url": client_x509_cert_url,
    "universe_domain": universe_domain
}
# Load Google Sheets IDs from environment variables
papers_spreadsheet_id = os.getenv("papers_spreadsheet_id")
density = os.getenv("density")
density_X = os.getenv("X")
density_Y = os.getenv("Y")
topics_spreadsheet_id = os.getenv("topics_spreadsheet_id")
spreadsheet_id =  {
    "papers": papers_spreadsheet_id,
    "density": density,
    "density_X": density_X,
    "density_Y": density_Y,
    "topics": topics_spreadsheet_id
}

# %%
# country_of_paper = results_df['country']
# results_df.drop(columns=['country'], inplace=True)
# # results_df.drop(columns=['country_of_paper'], inplace=True)
# results_df['country'] = df['country']
# # results_df['country_of_paper'] = country_of_paper

# %%
from data import googleSheets
import importlib

importlib.reload(googleSheets)

google_sheets = googleSheets.API(credentials_json=credenetials)

# Upload the results DataFrame to Google Sheets
google_sheets.replace(
    results_df, 
    spreadsheet_id=spreadsheet_id['papers'], 
    sheet_name='Sheet1'
    )
# Out:
# 2025-06-11 08:23:08,852 - API - INFO - Initializing Google Sheets API
# 2025-06-11 08:23:08,853 - API - INFO - Building Google Sheets service
# 2025-06-11 08:23:08,905 - googleapiclient.discovery_cache - INFO - file_cache is only supported with oauth2client<4.0.0
# 2025-06-11 08:23:08,907 - API - INFO - Google Sheets service built successfully
# 2025-06-11 08:23:08,907 - API - INFO - API initialized with batch size: 1000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       6 google_sheets = googleSheets.API(credentials_json=credenetials)
#       8 # Upload the results DataFrame to Google Sheets
#       9 google_sheets.replace(
# ---> 10     results_df,
#      11     spreadsheet_id=spreadsheet_id['papers'],
#      12     sheet_name='Sheet1'
#      13     )
#
# NameError: name 'results_df' is not defined
